# %% [markdown]
# # Programming Project - Unit 2
# *by Débora Azevedo, Eliseu Jayro, Francisco de Paiva and Igor Brandão*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Geolocation analysis and hypotheses should be explained in detail;

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - File input;
# - Tqdm progress bar
# - Requests;
# - urlopen;
# - HTTPError;

# %%
### Library necessary to run this IPython Notebook
# !pip install tqdm
# !pip install tabulate
# !pip install pandas-datareader
# !pip install requests

# %%
# Import pandas
import pandas as pd

# Import numpy library
import numpy as np

# Import tqdm progressing bar plugin
from tqdm import tqdm

# Import API libraries
import requests
import json
from pandas.io.json import json_normalize

# Imports to output the result as a Markdown
from IPython.display import display, Markdown
from tabulate import tabulate

# %% [markdown]
# <hr>

# %% [markdown]
# # I - API section
#
# ## API data retrieving
#
# #### In the cell bellow, we perform a connection with Health Graph API - Runkeeper.

# %%
# Access token
ACCESS_TOKEN = '25bc30d6dd6f4b99bbeb48e8619103b4'

# Base URI
api_URI = "http://api.runkeeper.com/fitnessActivities"

# Number of results
pageSize = 5000

# Final URI
url = '%s?pageSize=%s&access_token=%s' % \
    (api_URI, pageSize, ACCESS_TOKEN,)

# print(url)

# Receive the results from API
api_content = requests.get(url).json()

print(json.dumps(api_content, indent=1))
# Out:
# {
#  "items": [
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 256,
#    "start_time": "Fri, 26 Oct 2018 18:03:16",
#    "uri": "/fitnessActivities/1248977291",
#    "source": "RunKeeper",
#    "total_distance": 8151.82599416682,
#    "duration": 2272,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 193,
#    "start_time": "Fri, 26 Oct 2018 07:56:50",
#    "uri": "/fitnessActivities/1248977286",
#    "source": "RunKeeper",
#    "total_distance": 7900.92514314074,
#    "duration": 1555,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 127,
#    "start_time": "Wed, 24 Oct 2018 12:33:35",
#    "uri": "/fitnessActivities/1247963081",
#    "source": "RunKeeper",
#    "total_distance": 4127.19294558563,
#    "duration": 1123,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Wed, 24 Oct 2018 07:22:57",
#    "uri": "/fitnessActivities/1247963047",
#    "source": "RunKeeper",
#    "total_distance": 7933.16628975911,
#    "duration": 1478,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 158,
#    "start_time": "Tue, 23 Oct 2018 13:15:36",
#    "uri": "/fitnessActivities/1247963042",
#    "source": "RunKeeper",
#    "total_distance": 5281.13421648369,
#    "duration": 1222,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 203,
#    "start_time": "Fri, 19 Oct 2018 07:30:10",
#    "uri": "/fitnessActivities/1247963039",
#    "source": "RunKeeper",
#    "total_distance": 7546.2865221866,
#    "duration": 1497,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 252,
#    "start_time": "Wed, 17 Oct 2018 15:20:50",
#    "uri": "/fitnessActivities/1247963036",
#    "source": "RunKeeper",
#    "total_distance": 7992.05033929714,
#    "duration": 1983,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 196,
#    "start_time": "Wed, 17 Oct 2018 07:58:51",
#    "uri": "/fitnessActivities/1247963033",
#    "source": "RunKeeper",
#    "total_distance": 7807.02472791379,
#    "duration": 1546,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 282,
#    "start_time": "Tue, 9 Oct 2018 13:42:13",
#    "uri": "/fitnessActivities/1241059614",
#    "source": "RunKeeper",
#    "total_distance": 8791.48188226483,
#    "duration": 2514,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 195,
#    "start_time": "Tue, 9 Oct 2018 07:01:20",
#    "uri": "/fitnessActivities/1241059598",
#    "source": "RunKeeper",
#    "total_distance": 7944.65383852786,
#    "duration": 1464,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 293,
#    "start_time": "Fri, 5 Oct 2018 13:31:20",
#    "uri": "/fitnessActivities/1239128443",
#    "source": "RunKeeper",
#    "total_distance": 8646.50334772221,
#    "duration": 3009,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 198,
#    "start_time": "Fri, 5 Oct 2018 07:32:10",
#    "uri": "/fitnessActivities/1239108321",
#    "source": "RunKeeper",
#    "total_distance": 7561.66684939903,
#    "duration": 1483,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 234,
#    "start_time": "Tue, 2 Oct 2018 12:19:17",
#    "uri": "/fitnessActivities/1237705303",
#    "source": "RunKeeper",
#    "total_distance": 8010.3490461844,
#    "duration": 2047.514,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 215,
#    "start_time": "Tue, 2 Oct 2018 07:10:18",
#    "uri": "/fitnessActivities/1237576166",
#    "source": "RunKeeper",
#    "total_distance": 7911.28495446643,
#    "duration": 1650,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 379,
#    "start_time": "Thu, 27 Sep 2018 07:50:07",
#    "uri": "/fitnessActivities/1237541305",
#    "source": "RunKeeper",
#    "total_distance": 10472.9103979573,
#    "duration": 3331,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 230,
#    "start_time": "Tue, 25 Sep 2018 12:24:03",
#    "uri": "/fitnessActivities/1237541300",
#    "source": "RunKeeper",
#    "total_distance": 7972.87017356226,
#    "duration": 1948,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 192,
#    "start_time": "Tue, 25 Sep 2018 07:42:44",
#    "uri": "/fitnessActivities/1237541296",
#    "source": "RunKeeper",
#    "total_distance": 7530.84942320515,
#    "duration": 1416,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 204,
#    "start_time": "Thu, 20 Sep 2018 13:24:59",
#    "uri": "/fitnessActivities/1237541244",
#    "source": "RunKeeper",
#    "total_distance": 7113.37860709297,
#    "duration": 1674,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 209,
#    "start_time": "Thu, 20 Sep 2018 07:12:25",
#    "uri": "/fitnessActivities/1232056305",
#    "source": "RunKeeper",
#    "total_distance": 7935.35675502479,
#    "duration": 1558,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 236,
#    "start_time": "Tue, 18 Sep 2018 12:54:14",
#    "uri": "/fitnessActivities/1232056300",
#    "source": "RunKeeper",
#    "total_distance": 7396.22085425344,
#    "duration": 1984,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 198,
#    "start_time": "Tue, 18 Sep 2018 07:22:49",
#    "uri": "/fitnessActivities/1232056296",
#    "source": "RunKeeper",
#    "total_distance": 7976.79742193221,
#    "duration": 1523,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 504,
#    "start_time": "Thu, 13 Sep 2018 14:03:45",
#    "uri": "/fitnessActivities/1232056293",
#    "source": "RunKeeper",
#    "total_distance": 19522.7108066581,
#    "duration": 3992,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 197,
#    "start_time": "Thu, 13 Sep 2018 07:44:54",
#    "uri": "/fitnessActivities/1232056068",
#    "source": "RunKeeper",
#    "total_distance": 7961.15946222771,
#    "duration": 1492,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 228,
#    "start_time": "Tue, 11 Sep 2018 13:36:48",
#    "uri": "/fitnessActivities/1232056058",
#    "source": "RunKeeper",
#    "total_distance": 8050.79049067249,
#    "duration": 1943,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 196,
#    "start_time": "Tue, 11 Sep 2018 07:56:25",
#    "uri": "/fitnessActivities/1232056039",
#    "source": "RunKeeper",
#    "total_distance": 7964.81807414556,
#    "duration": 1546,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 227,
#    "start_time": "Wed, 5 Sep 2018 12:59:40",
#    "uri": "/fitnessActivities/1232056036",
#    "source": "RunKeeper",
#    "total_distance": 7956.91601594747,
#    "duration": 1836,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 198,
#    "start_time": "Wed, 5 Sep 2018 07:18:07",
#    "uri": "/fitnessActivities/1232056028",
#    "source": "RunKeeper",
#    "total_distance": 7934.98886802089,
#    "duration": 1501,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 247,
#    "start_time": "Fri, 31 Aug 2018 13:46:10",
#    "uri": "/fitnessActivities/1221821645",
#    "source": "RunKeeper",
#    "total_distance": 8595.08291408208,
#    "duration": 2122,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Fri, 31 Aug 2018 07:00:07",
#    "uri": "/fitnessActivities/1221793323",
#    "source": "RunKeeper",
#    "total_distance": 7890.31892164946,
#    "duration": 1438,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 205,
#    "start_time": "Wed, 29 Aug 2018 13:05:19",
#    "uri": "/fitnessActivities/1221793316",
#    "source": "RunKeeper",
#    "total_distance": 7059.59912966878,
#    "duration": 1734,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 194,
#    "start_time": "Wed, 29 Aug 2018 07:02:00",
#    "uri": "/fitnessActivities/1220779094",
#    "source": "RunKeeper",
#    "total_distance": 7991.18205711085,
#    "duration": 1177,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 251,
#    "start_time": "Tue, 28 Aug 2018 16:47:58",
#    "uri": "/fitnessActivities/1220371653",
#    "source": "RunKeeper",
#    "total_distance": 7462.7607324441,
#    "duration": 2256,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 229,
#    "start_time": "Tue, 28 Aug 2018 10:00:13",
#    "uri": "/fitnessActivities/1220167250",
#    "source": "RunKeeper",
#    "total_distance": 7871.25798869614,
#    "duration": 1734,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 205,
#    "start_time": "Fri, 24 Aug 2018 07:58:25",
#    "uri": "/fitnessActivities/1218036090",
#    "source": "RunKeeper",
#    "total_distance": 7936.9862572633,
#    "duration": 1543,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 202,
#    "start_time": "Thu, 23 Aug 2018 14:13:13",
#    "uri": "/fitnessActivities/1217721948",
#    "source": "RunKeeper",
#    "total_distance": 7052.72328202818,
#    "duration": 1607,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 197,
#    "start_time": "Thu, 23 Aug 2018 07:52:33",
#    "uri": "/fitnessActivities/1217721945",
#    "source": "RunKeeper",
#    "total_distance": 7957.77072908257,
#    "duration": 1453,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 602,
#    "start_time": "Fri, 17 Aug 2018 15:40:24",
#    "uri": "/fitnessActivities/1217721941",
#    "source": "RunKeeper",
#    "total_distance": 20371.7759911225,
#    "duration": 4467,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 195,
#    "start_time": "Fri, 17 Aug 2018 07:12:26",
#    "uri": "/fitnessActivities/1217721937",
#    "source": "RunKeeper",
#    "total_distance": 7527.06484802918,
#    "duration": 1273,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 230,
#    "start_time": "Thu, 16 Aug 2018 16:28:17",
#    "uri": "/fitnessActivities/1213990570",
#    "source": "RunKeeper",
#    "total_distance": 8057.81215684419,
#    "duration": 1810,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 210,
#    "start_time": "Thu, 16 Aug 2018 07:15:48",
#    "uri": "/fitnessActivities/1213980180",
#    "source": "RunKeeper",
#    "total_distance": 7984.08547351639,
#    "duration": 1481,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 248,
#    "start_time": "Tue, 14 Aug 2018 13:33:37",
#    "uri": "/fitnessActivities/1212813981",
#    "source": "RunKeeper",
#    "total_distance": 8341.23297641887,
#    "duration": 2087,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 209,
#    "start_time": "Tue, 14 Aug 2018 07:17:28",
#    "uri": "/fitnessActivities/1212783052",
#    "source": "RunKeeper",
#    "total_distance": 7893.4166418797,
#    "duration": 1607,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 248,
#    "start_time": "Fri, 10 Aug 2018 17:56:41",
#    "uri": "/fitnessActivities/1212783048",
#    "source": "RunKeeper",
#    "total_distance": 8177.41298050943,
#    "duration": 2335,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 211,
#    "start_time": "Fri, 10 Aug 2018 07:33:52",
#    "uri": "/fitnessActivities/1210777044",
#    "source": "RunKeeper",
#    "total_distance": 7909.32681193278,
#    "duration": 1539,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 244,
#    "start_time": "Thu, 9 Aug 2018 15:33:08",
#    "uri": "/fitnessActivities/1210271843",
#    "source": "RunKeeper",
#    "total_distance": 8353.28513557426,
#    "duration": 2066,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 236,
#    "start_time": "Thu, 9 Aug 2018 06:52:02",
#    "uri": "/fitnessActivities/1210256071",
#    "source": "RunKeeper",
#    "total_distance": 7552.43022045406,
#    "duration": 1879,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 224,
#    "start_time": "Wed, 8 Aug 2018 12:57:06",
#    "uri": "/fitnessActivities/1209661383",
#    "source": "RunKeeper",
#    "total_distance": 7935.04570986493,
#    "duration": 1804,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 204,
#    "start_time": "Wed, 8 Aug 2018 06:48:45",
#    "uri": "/fitnessActivities/1209647123",
#    "source": "RunKeeper",
#    "total_distance": 7917.25264681245,
#    "duration": 1539,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 204,
#    "start_time": "Tue, 7 Aug 2018 16:46:05",
#    "uri": "/fitnessActivities/1209473345",
#    "source": "RunKeeper",
#    "total_distance": 7051.16042509807,
#    "duration": 1776,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 230,
#    "start_time": "Tue, 7 Aug 2018 07:47:31",
#    "uri": "/fitnessActivities/1209473340",
#    "source": "RunKeeper",
#    "total_distance": 7941.39411129561,
#    "duration": 1793,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 246,
#    "start_time": "Thu, 2 Aug 2018 17:54:52",
#    "uri": "/fitnessActivities/1209473334",
#    "source": "RunKeeper",
#    "total_distance": 8158.0369677723,
#    "duration": 2091,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 203,
#    "start_time": "Thu, 2 Aug 2018 07:37:22",
#    "uri": "/fitnessActivities/1206631817",
#    "source": "RunKeeper",
#    "total_distance": 7946.07536623127,
#    "duration": 1450,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 221,
#    "start_time": "Wed, 1 Aug 2018 14:08:38",
#    "uri": "/fitnessActivities/1206016406",
#    "source": "RunKeeper",
#    "total_distance": 7936.61837611393,
#    "duration": 1730,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 203,
#    "start_time": "Wed, 1 Aug 2018 08:16:14",
#    "uri": "/fitnessActivities/1206016395",
#    "source": "RunKeeper",
#    "total_distance": 7942.69129603818,
#    "duration": 1319,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Tue, 31 Jul 2018 16:12:23",
#    "uri": "/fitnessActivities/1205520224",
#    "source": "RunKeeper",
#    "total_distance": 7091.20251100109,
#    "duration": 1555,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 213,
#    "start_time": "Tue, 31 Jul 2018 07:14:04",
#    "uri": "/fitnessActivities/1205506700",
#    "source": "RunKeeper",
#    "total_distance": 7919.77841981182,
#    "duration": 1472,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 240,
#    "start_time": "Thu, 26 Jul 2018 17:46:15",
#    "uri": "/fitnessActivities/1203056263",
#    "source": "RunKeeper",
#    "total_distance": 7930.54068687709,
#    "duration": 1954,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 199,
#    "start_time": "Thu, 26 Jul 2018 08:33:13",
#    "uri": "/fitnessActivities/1203056249",
#    "source": "RunKeeper",
#    "total_distance": 7916.7007892622,
#    "duration": 1373,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 331,
#    "start_time": "Wed, 25 Jul 2018 13:47:13",
#    "uri": "/fitnessActivities/1202487043",
#    "source": "RunKeeper",
#    "total_distance": 8375.2777078165,
#    "duration": 2486,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Wed, 25 Jul 2018 07:57:42",
#    "uri": "/fitnessActivities/1202456675",
#    "source": "RunKeeper",
#    "total_distance": 7956.03659706273,
#    "duration": 1426,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 176,
#    "start_time": "Tue, 24 Jul 2018 15:00:24",
#    "uri": "/fitnessActivities/1201964782",
#    "source": "RunKeeper",
#    "total_distance": 5253.8394042946,
#    "duration": 1550,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 182,
#    "start_time": "Fri, 20 Jul 2018 12:47:04",
#    "uri": "/fitnessActivities/1201950707",
#    "source": "RunKeeper",
#    "total_distance": 5713.20106050275,
#    "duration": 1520,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Fri, 20 Jul 2018 08:04:29",
#    "uri": "/fitnessActivities/1201950695",
#    "source": "RunKeeper",
#    "total_distance": 7544.07734127961,
#    "duration": 1338,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 212,
#    "start_time": "Thu, 19 Jul 2018 16:11:12",
#    "uri": "/fitnessActivities/1199405137",
#    "source": "RunKeeper",
#    "total_distance": 7092.04084494765,
#    "duration": 1974,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 195,
#    "start_time": "Thu, 19 Jul 2018 08:41:37",
#    "uri": "/fitnessActivities/1199405132",
#    "source": "RunKeeper",
#    "total_distance": 7931.52425566631,
#    "duration": 1403,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 237,
#    "start_time": "Wed, 18 Jul 2018 17:42:56",
#    "uri": "/fitnessActivities/1198893055",
#    "source": "RunKeeper",
#    "total_distance": 8002.39499962498,
#    "duration": 2000,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 204,
#    "start_time": "Wed, 18 Jul 2018 08:01:29",
#    "uri": "/fitnessActivities/1198881215",
#    "source": "RunKeeper",
#    "total_distance": 7919.61918575663,
#    "duration": 1466,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 205,
#    "start_time": "Tue, 17 Jul 2018 16:10:50",
#    "uri": "/fitnessActivities/1198881210",
#    "source": "RunKeeper",
#    "total_distance": 7091.73526951626,
#    "duration": 1717,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 202,
#    "start_time": "Tue, 17 Jul 2018 07:49:40",
#    "uri": "/fitnessActivities/1198277210",
#    "source": "RunKeeper",
#    "total_distance": 7927.886096402,
#    "duration": 1351,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 231,
#    "start_time": "Fri, 13 Jul 2018 14:38:37",
#    "uri": "/fitnessActivities/1196172652",
#    "source": "RunKeeper",
#    "total_distance": 8059.38365275665,
#    "duration": 1977,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 205,
#    "start_time": "Fri, 13 Jul 2018 07:56:33",
#    "uri": "/fitnessActivities/1196133453",
#    "source": "RunKeeper",
#    "total_distance": 7944.68452377758,
#    "duration": 1481,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 246,
#    "start_time": "Thu, 12 Jul 2018 17:41:19",
#    "uri": "/fitnessActivities/1195718471",
#    "source": "RunKeeper",
#    "total_distance": 7965.62903066182,
#    "duration": 2134,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Thu, 12 Jul 2018 07:45:18",
#    "uri": "/fitnessActivities/1195706781",
#    "source": "RunKeeper",
#    "total_distance": 7928.62949313884,
#    "duration": 1537,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 341,
#    "start_time": "Thu, 5 Jul 2018 12:06:01",
#    "uri": "/fitnessActivities/1191889236",
#    "source": "RunKeeper",
#    "total_distance": 10657.5938108823,
#    "duration": 2881,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 206,
#    "start_time": "Thu, 5 Jul 2018 07:20:09",
#    "uri": "/fitnessActivities/1191889234",
#    "source": "RunKeeper",
#    "total_distance": 7937.27826258878,
#    "duration": 1351,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 196,
#    "start_time": "Wed, 4 Jul 2018 07:01:09",
#    "uri": "/fitnessActivities/1191889228",
#    "source": "RunKeeper",
#    "total_distance": 7595.26010425884,
#    "duration": 1339,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 312,
#    "start_time": "Tue, 3 Jul 2018 13:29:31",
#    "uri": "/fitnessActivities/1191889225",
#    "source": "RunKeeper",
#    "total_distance": 11155.383754896,
#    "duration": 2461,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 198,
#    "start_time": "Tue, 3 Jul 2018 06:31:43",
#    "uri": "/fitnessActivities/1191889222",
#    "source": "RunKeeper",
#    "total_distance": 7546.40521250835,
#    "duration": 1320,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 232,
#    "start_time": "Thu, 28 Jun 2018 13:46:57",
#    "uri": "/fitnessActivities/1188342246",
#    "source": "RunKeeper",
#    "total_distance": 7922.09082882782,
#    "duration": 1916,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 208,
#    "start_time": "Thu, 28 Jun 2018 07:06:57",
#    "uri": "/fitnessActivities/1188342235",
#    "source": "RunKeeper",
#    "total_distance": 7956.93040854628,
#    "duration": 1404,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 232,
#    "start_time": "Wed, 27 Jun 2018 17:15:42",
#    "uri": "/fitnessActivities/1187937389",
#    "source": "RunKeeper",
#    "total_distance": 8097.78700503481,
#    "duration": 2018,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 203,
#    "start_time": "Wed, 27 Jun 2018 07:55:21",
#    "uri": "/fitnessActivities/1187937370",
#    "source": "RunKeeper",
#    "total_distance": 7947.96864392568,
#    "duration": 1501,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 215,
#    "start_time": "Thu, 21 Jun 2018 16:54:01",
#    "uri": "/fitnessActivities/1184768910",
#    "source": "RunKeeper",
#    "total_distance": 7093.90431626102,
#    "duration": 1803,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 208,
#    "start_time": "Thu, 21 Jun 2018 07:14:11",
#    "uri": "/fitnessActivities/1184720565",
#    "source": "RunKeeper",
#    "total_distance": 7577.02061463589,
#    "duration": 1354,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 228,
#    "start_time": "Wed, 20 Jun 2018 16:33:00",
#    "uri": "/fitnessActivities/1184236496",
#    "source": "RunKeeper",
#    "total_distance": 7924.11285661681,
#    "duration": 1874,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 213,
#    "start_time": "Wed, 20 Jun 2018 07:08:26",
#    "uri": "/fitnessActivities/1184224020",
#    "source": "RunKeeper",
#    "total_distance": 7957.52333375111,
#    "duration": 1413,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 233,
#    "start_time": "Tue, 19 Jun 2018 17:23:10",
#    "uri": "/fitnessActivities/1183726261",
#    "source": "RunKeeper",
#    "total_distance": 7975.58945515032,
#    "duration": 1835,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 199,
#    "start_time": "Tue, 19 Jun 2018 06:55:32",
#    "uri": "/fitnessActivities/1183726259",
#    "source": "RunKeeper",
#    "total_distance": 7927.79025759383,
#    "duration": 1501,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 226,
#    "start_time": "Fri, 15 Jun 2018 14:03:01",
#    "uri": "/fitnessActivities/1183726253",
#    "source": "RunKeeper",
#    "total_distance": 7927.40111201032,
#    "duration": 1825,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Fri, 15 Jun 2018 07:25:43",
#    "uri": "/fitnessActivities/1181404469",
#    "source": "RunKeeper",
#    "total_distance": 7946.08527312559,
#    "duration": 1314,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 261,
#    "start_time": "Thu, 14 Jun 2018 14:13:34",
#    "uri": "/fitnessActivities/1181082485",
#    "source": "RunKeeper",
#    "total_distance": 9425.58627422226,
#    "duration": 2077,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 206,
#    "start_time": "Thu, 14 Jun 2018 06:52:52",
#    "uri": "/fitnessActivities/1181064641",
#    "source": "RunKeeper",
#    "total_distance": 7543.28846032002,
#    "duration": 1419,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 272,
#    "start_time": "Wed, 13 Jun 2018 13:53:26",
#    "uri": "/fitnessActivities/1180563508",
#    "source": "RunKeeper",
#    "total_distance": 8046.88205018331,
#    "duration": 2461,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Wed, 13 Jun 2018 07:15:21",
#    "uri": "/fitnessActivities/1180537354",
#    "source": "RunKeeper",
#    "total_distance": 7966.15833864404,
#    "duration": 1415,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 345,
#    "start_time": "Tue, 12 Jun 2018 15:27:27",
#    "uri": "/fitnessActivities/1180068455",
#    "source": "RunKeeper",
#    "total_distance": 8378.87741916106,
#    "duration": 3253,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Tue, 12 Jun 2018 06:53:48",
#    "uri": "/fitnessActivities/1180036004",
#    "source": "RunKeeper",
#    "total_distance": 7920.01582145066,
#    "duration": 1484,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 239,
#    "start_time": "Thu, 7 Jun 2018 16:19:50",
#    "uri": "/fitnessActivities/1177415544",
#    "source": "RunKeeper",
#    "total_distance": 7912.43133646559,
#    "duration": 1960,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 199,
#    "start_time": "Thu, 7 Jun 2018 07:59:02",
#    "uri": "/fitnessActivities/1177162334",
#    "source": "RunKeeper",
#    "total_distance": 7934.05733322881,
#    "duration": 1569,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 265,
#    "start_time": "Tue, 5 Jun 2018 16:00:53",
#    "uri": "/fitnessActivities/1177149557",
#    "source": "RunKeeper",
#    "total_distance": 7973.54729344993,
#    "duration": 2163,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 195,
#    "start_time": "Tue, 5 Jun 2018 07:46:32",
#    "uri": "/fitnessActivities/1176022619",
#    "source": "RunKeeper",
#    "total_distance": 7950.37719959947,
#    "duration": 1387,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 216,
#    "start_time": "Wed, 30 May 2018 14:28:34",
#    "uri": "/fitnessActivities/1173063200",
#    "source": "RunKeeper",
#    "total_distance": 7386.05402641946,
#    "duration": 1777,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 199,
#    "start_time": "Wed, 30 May 2018 07:22:15",
#    "uri": "/fitnessActivities/1172756109",
#    "source": "RunKeeper",
#    "total_distance": 7940.25699060042,
#    "duration": 1306,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 221,
#    "start_time": "Tue, 29 May 2018 17:31:12",
#    "uri": "/fitnessActivities/1172500436",
#    "source": "RunKeeper",
#    "total_distance": 7942.88542727761,
#    "duration": 1726,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 202,
#    "start_time": "Tue, 29 May 2018 06:50:25",
#    "uri": "/fitnessActivities/1172490494",
#    "source": "RunKeeper",
#    "total_distance": 7954.11232953135,
#    "duration": 1282,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 207,
#    "start_time": "Fri, 25 May 2018 14:36:03",
#    "uri": "/fitnessActivities/1170261042",
#    "source": "RunKeeper",
#    "total_distance": 7166.34774412719,
#    "duration": 1687,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 198,
#    "start_time": "Fri, 25 May 2018 08:12:56",
#    "uri": "/fitnessActivities/1170233680",
#    "source": "RunKeeper",
#    "total_distance": 7540.59038963516,
#    "duration": 1377,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 199,
#    "start_time": "Thu, 24 May 2018 18:55:53",
#    "uri": "/fitnessActivities/1169843019",
#    "source": "RunKeeper",
#    "total_distance": 7391.36745729282,
#    "duration": 1515,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 196,
#    "start_time": "Thu, 24 May 2018 07:24:30",
#    "uri": "/fitnessActivities/1169834377",
#    "source": "RunKeeper",
#    "total_distance": 7520.39077655349,
#    "duration": 1334,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 210,
#    "start_time": "Wed, 23 May 2018 14:11:08",
#    "uri": "/fitnessActivities/1169144944",
#    "source": "RunKeeper",
#    "total_distance": 7443.02512288903,
#    "duration": 1678,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 195,
#    "start_time": "Wed, 23 May 2018 07:38:26",
#    "uri": "/fitnessActivities/1169123144",
#    "source": "RunKeeper",
#    "total_distance": 7507.11038116269,
#    "duration": 1316,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 215,
#    "start_time": "Tue, 22 May 2018 14:18:17",
#    "uri": "/fitnessActivities/1169123125",
#    "source": "RunKeeper",
#    "total_distance": 7354.20397959863,
#    "duration": 1690,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 194,
#    "start_time": "Tue, 22 May 2018 07:53:29",
#    "uri": "/fitnessActivities/1168369561",
#    "source": "RunKeeper",
#    "total_distance": 7531.96424532649,
#    "duration": 1328,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 621,
#    "start_time": "Fri, 18 May 2018 15:31:10",
#    "uri": "/fitnessActivities/1166352274",
#    "source": "RunKeeper",
#    "total_distance": 20399.5582384638,
#    "duration": 4801,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 216,
#    "start_time": "Fri, 18 May 2018 08:00:20",
#    "uri": "/fitnessActivities/1166327212",
#    "source": "RunKeeper",
#    "total_distance": 8155.09444416411,
#    "duration": 1763,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 235,
#    "start_time": "Thu, 17 May 2018 17:20:26",
#    "uri": "/fitnessActivities/1165898370",
#    "source": "RunKeeper",
#    "total_distance": 7972.25160907191,
#    "duration": 1902,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 223,
#    "start_time": "Thu, 17 May 2018 07:56:37",
#    "uri": "/fitnessActivities/1165888156",
#    "source": "RunKeeper",
#    "total_distance": 7939.14037307977,
#    "duration": 1615,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 510,
#    "start_time": "Wed, 16 May 2018 15:27:54",
#    "uri": "/fitnessActivities/1165342915",
#    "source": "RunKeeper",
#    "total_distance": 20067.3606103592,
#    "duration": 3932,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 210,
#    "start_time": "Wed, 16 May 2018 07:50:00",
#    "uri": "/fitnessActivities/1165305685",
#    "source": "RunKeeper",
#    "total_distance": 8024.31300169095,
#    "duration": 1441,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 207,
#    "start_time": "Tue, 15 May 2018 16:30:22",
#    "uri": "/fitnessActivities/1165305677",
#    "source": "RunKeeper",
#    "total_distance": 7037.84847097626,
#    "duration": 1647,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Tue, 15 May 2018 07:27:21",
#    "uri": "/fitnessActivities/1164464928",
#    "source": "RunKeeper",
#    "total_distance": 7944.49632552632,
#    "duration": 1427,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 387,
#    "start_time": "Thu, 10 May 2018 14:13:22",
#    "uri": "/fitnessActivities/1161944827",
#    "source": "RunKeeper",
#    "total_distance": 8518.28912602852,
#    "duration": 3751,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 224,
#    "start_time": "Thu, 10 May 2018 07:47:59",
#    "uri": "/fitnessActivities/1161910765",
#    "source": "RunKeeper",
#    "total_distance": 8188.75259507603,
#    "duration": 1688,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 659,
#    "start_time": "Wed, 9 May 2018 13:08:03",
#    "uri": "/fitnessActivities/1161337389",
#    "source": "RunKeeper",
#    "total_distance": 12774.7402366925,
#    "duration": 6600,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 203,
#    "start_time": "Wed, 9 May 2018 07:14:20",
#    "uri": "/fitnessActivities/1161275661",
#    "source": "RunKeeper",
#    "total_distance": 7956.71619504537,
#    "duration": 1419,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 250,
#    "start_time": "Thu, 3 May 2018 17:35:15",
#    "uri": "/fitnessActivities/1157952472",
#    "source": "RunKeeper",
#    "total_distance": 8181.55151420816,
#    "duration": 2133,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 210,
#    "start_time": "Thu, 3 May 2018 07:00:40",
#    "uri": "/fitnessActivities/1157940534",
#    "source": "RunKeeper",
#    "total_distance": 7632.42054988497,
#    "duration": 1517,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 203,
#    "start_time": "Wed, 2 May 2018 14:36:21",
#    "uri": "/fitnessActivities/1157339192",
#    "source": "RunKeeper",
#    "total_distance": 7045.59366793894,
#    "duration": 1677,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 215,
#    "start_time": "Wed, 2 May 2018 06:58:05",
#    "uri": "/fitnessActivities/1157339184",
#    "source": "RunKeeper",
#    "total_distance": 7985.30503052478,
#    "duration": 1506,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 226,
#    "start_time": "Mon, 30 Apr 2018 13:22:02",
#    "uri": "/fitnessActivities/1157339174",
#    "source": "RunKeeper",
#    "total_distance": 5302.58169032014,
#    "duration": 1974,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 254,
#    "start_time": "Fri, 27 Apr 2018 15:17:16",
#    "uri": "/fitnessActivities/1154568046",
#    "source": "RunKeeper",
#    "total_distance": 9442.5865038205,
#    "duration": 2013,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 197,
#    "start_time": "Fri, 27 Apr 2018 07:54:46",
#    "uri": "/fitnessActivities/1154568043",
#    "source": "RunKeeper",
#    "total_distance": 7935.38019437731,
#    "duration": 1442,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 212,
#    "start_time": "Wed, 25 Apr 2018 07:51:46",
#    "uri": "/fitnessActivities/1154568038",
#    "source": "RunKeeper",
#    "total_distance": 7945.72484208936,
#    "duration": 1582,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 201,
#    "start_time": "Tue, 24 Apr 2018 08:00:59",
#    "uri": "/fitnessActivities/1154567966",
#    "source": "RunKeeper",
#    "total_distance": 7562.13597569603,
#    "duration": 1320,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 239,
#    "start_time": "Mon, 23 Apr 2018 16:51:10",
#    "uri": "/fitnessActivities/1154567964",
#    "source": "RunKeeper",
#    "total_distance": 7936.70059451742,
#    "duration": 1811,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 219,
#    "start_time": "Mon, 23 Apr 2018 06:54:00",
#    "uri": "/fitnessActivities/1154567961",
#    "source": "RunKeeper",
#    "total_distance": 7974.46776028658,
#    "duration": 1605,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 317,
#    "start_time": "Thu, 19 Apr 2018 14:34:54",
#    "uri": "/fitnessActivities/1154567958",
#    "source": "RunKeeper",
#    "total_distance": 8174.73025107923,
#    "duration": 2741,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 208,
#    "start_time": "Thu, 19 Apr 2018 07:42:49",
#    "uri": "/fitnessActivities/1154567954",
#    "source": "RunKeeper",
#    "total_distance": 7941.43716254774,
#    "duration": 1362,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 547,
#    "start_time": "Wed, 18 Apr 2018 16:08:08",
#    "uri": "/fitnessActivities/1149757907",
#    "source": "RunKeeper",
#    "total_distance": 19545.6009569659,
#    "duration": 4136,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 209,
#    "start_time": "Thu, 12 Apr 2018 06:46:21",
#    "uri": "/fitnessActivities/1149728366",
#    "source": "RunKeeper",
#    "total_distance": 7949.06007591397,
#    "duration": 1399,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 271,
#    "start_time": "Wed, 11 Apr 2018 07:49:48",
#    "uri": "/fitnessActivities/1149728356",
#    "source": "RunKeeper",
#    "total_distance": 8455.64688440663,
#    "duration": 2118,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 388,
#    "start_time": "Tue, 10 Apr 2018 07:28:18",
#    "uri": "/fitnessActivities/1149728343",
#    "source": "RunKeeper",
#    "total_distance": 8471.10661955607,
#    "duration": 3479,
#    "type": "Cycling",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 208,
#    "start_time": "Wed, 4 Apr 2018 07:25:42",
#    "uri": "/fitnessActivities/1145053973",
#    "source": "RunKeeper",
# ...
#    "duration": 2367,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 228,
#    "start_time": "Sun, 14 Aug 2016 14:58:01",
#    "uri": "/fitnessActivities/844532207",
#    "source": "RunKeeper",
#    "total_distance": 3470.17075871582,
#    "duration": 2036,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 182,
#    "start_time": "Sun, 14 Aug 2016 14:24:10",
#    "uri": "/fitnessActivities/844501490",
#    "source": "RunKeeper",
#    "total_distance": 2418.75009664913,
#    "duration": 794,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 261,
#    "start_time": "Sun, 31 Jul 2016 12:30:27",
#    "uri": "/fitnessActivities/835895196",
#    "source": "RunKeeper",
#    "total_distance": 3526.11015333881,
#    "duration": 1109,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 193,
#    "start_time": "Sun, 31 Jul 2016 11:39:30",
#    "uri": "/fitnessActivities/835895188",
#    "source": "RunKeeper",
#    "total_distance": 2272.81277948962,
#    "duration": 2982,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 420,
#    "start_time": "Sun, 19 Jun 2016 15:54:04",
#    "uri": "/fitnessActivities/810514835",
#    "source": "RunKeeper",
#    "total_distance": 5850.37512732216,
#    "duration": 2271,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 781,
#    "start_time": "Sat, 18 Jun 2016 07:13:03",
#    "uri": "/fitnessActivities/809687187",
#    "source": "RunKeeper",
#    "total_distance": 7463.43806205611,
#    "duration": 8106,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 373,
#    "start_time": "Sat, 18 Jun 2016 06:08:27",
#    "uri": "/fitnessActivities/809687157",
#    "source": "RunKeeper",
#    "total_distance": 4123.84686293397,
#    "duration": 2563,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 458,
#    "start_time": "Wed, 15 Jun 2016 06:02:52",
#    "uri": "/fitnessActivities/807853214",
#    "source": "RunKeeper",
#    "total_distance": 6129.74843199285,
#    "duration": 2087,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 59,
#    "start_time": "Mon, 13 Jun 2016 17:06:40",
#    "uri": "/fitnessActivities/806924800",
#    "source": "RunKeeper",
#    "total_distance": 615.714617224684,
#    "duration": 789,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 299,
#    "start_time": "Mon, 13 Jun 2016 15:03:52",
#    "uri": "/fitnessActivities/806901919",
#    "source": "RunKeeper",
#    "total_distance": 549.757560743894,
#    "duration": 606,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 450,
#    "start_time": "Mon, 13 Jun 2016 05:50:21",
#    "uri": "/fitnessActivities/806547477",
#    "source": "RunKeeper",
#    "total_distance": 5756.30000050235,
#    "duration": 1594,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 451,
#    "start_time": "Fri, 10 Jun 2016 05:58:37",
#    "uri": "/fitnessActivities/804841603",
#    "source": "RunKeeper",
#    "total_distance": 5797.34713357958,
#    "duration": 1634,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 429,
#    "start_time": "Mon, 23 May 2016 06:08:33",
#    "uri": "/fitnessActivities/793442865",
#    "source": "RunKeeper",
#    "total_distance": 5884.05329187354,
#    "duration": 2209,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 455,
#    "start_time": "Mon, 16 May 2016 05:54:44",
#    "uri": "/fitnessActivities/788769831",
#    "source": "RunKeeper",
#    "total_distance": 5814.90671752075,
#    "duration": 1661,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 451,
#    "start_time": "Sat, 14 May 2016 06:09:23",
#    "uri": "/fitnessActivities/787533188",
#    "source": "RunKeeper",
#    "total_distance": 5835.27134531731,
#    "duration": 1862,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 453,
#    "start_time": "Thu, 5 May 2016 05:43:14",
#    "uri": "/fitnessActivities/781785039",
#    "source": "RunKeeper",
#    "total_distance": 5786.59705963899,
#    "duration": 1640,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 447,
#    "start_time": "Tue, 3 May 2016 05:49:35",
#    "uri": "/fitnessActivities/780351088",
#    "source": "RunKeeper",
#    "total_distance": 5887.67166192717,
#    "duration": 1812,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 456,
#    "start_time": "Wed, 20 Apr 2016 05:51:15",
#    "uri": "/fitnessActivities/772361130",
#    "source": "RunKeeper",
#    "total_distance": 5734.59075257851,
#    "duration": 1837,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 63,
#    "start_time": "Mon, 18 Apr 2016 06:19:21",
#    "uri": "/fitnessActivities/770943625",
#    "source": "RunKeeper",
#    "total_distance": 1047.1593087184,
#    "duration": 450,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 565,
#    "start_time": "Mon, 18 Apr 2016 05:50:48",
#    "uri": "/fitnessActivities/770943610",
#    "source": "RunKeeper",
#    "total_distance": 5782.77043463861,
#    "duration": 1586,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 458,
#    "start_time": "Mon, 11 Apr 2016 05:23:04",
#    "uri": "/fitnessActivities/766282546",
#    "source": "RunKeeper",
#    "total_distance": 5895.7589925569,
#    "duration": 1631,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 660,
#    "start_time": "Thu, 7 Apr 2016 07:34:36",
#    "uri": "/fitnessActivities/764018100",
#    "source": "RunKeeper",
#    "total_distance": 3698.48518715936,
#    "duration": 8038,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 435,
#    "start_time": "Tue, 29 Mar 2016 05:38:59",
#    "uri": "/fitnessActivities/759716642",
#    "source": "RunKeeper",
#    "total_distance": 5990.80532600518,
#    "duration": 2365,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 454,
#    "start_time": "Wed, 23 Mar 2016 06:08:51",
#    "uri": "/fitnessActivities/755079850",
#    "source": "RunKeeper",
#    "total_distance": 5749.38159142367,
#    "duration": 1640,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 455,
#    "start_time": "Mon, 21 Mar 2016 05:57:29",
#    "uri": "/fitnessActivities/753860205",
#    "source": "RunKeeper",
#    "total_distance": 5789.02666560211,
#    "duration": 1682,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 49,
#    "start_time": "Sun, 20 Mar 2016 17:04:57",
#    "uri": "/fitnessActivities/753646484",
#    "source": "RunKeeper",
#    "total_distance": 779.129464701952,
#    "duration": 261,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 447,
#    "start_time": "Mon, 14 Mar 2016 05:52:20",
#    "uri": "/fitnessActivities/749797852",
#    "source": "RunKeeper",
#    "total_distance": 5674.95440749925,
#    "duration": 1636,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 75,
#    "start_time": "Tue, 8 Mar 2016 13:22:25",
#    "uri": "/fitnessActivities/747371294",
#    "source": "RunKeeper",
#    "total_distance": 1213.07733323399,
#    "duration": 899,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 462,
#    "start_time": "Mon, 7 Mar 2016 06:03:09",
#    "uri": "/fitnessActivities/745796497",
#    "source": "RunKeeper",
#    "total_distance": 5838.98572316034,
#    "duration": 1692,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 253,
#    "start_time": "Sun, 6 Mar 2016 13:53:27",
#    "uri": "/fitnessActivities/745656183",
#    "source": "RunKeeper",
#    "total_distance": 3927.28664301713,
#    "duration": 3506,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 101,
#    "start_time": "Sun, 6 Mar 2016 11:23:33",
#    "uri": "/fitnessActivities/745656175",
#    "source": "RunKeeper",
#    "total_distance": 1593.60881674515,
#    "duration": 1567,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 489,
#    "start_time": "Thu, 3 Mar 2016 05:52:24",
#    "uri": "/fitnessActivities/743736231",
#    "source": "RunKeeper",
#    "total_distance": 6154.28759223911,
#    "duration": 1821,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 105,
#    "start_time": "Wed, 2 Mar 2016 18:26:34",
#    "uri": "/fitnessActivities/743518140",
#    "source": "RunKeeper",
#    "total_distance": 844.110303054361,
#    "duration": 2931,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 467,
#    "start_time": "Mon, 29 Feb 2016 06:05:33",
#    "uri": "/fitnessActivities/742107339",
#    "source": "RunKeeper",
#    "total_distance": 5805.83679757534,
#    "duration": 1917,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 205,
#    "start_time": "Sun, 28 Feb 2016 10:41:56",
#    "uri": "/fitnessActivities/742025830",
#    "source": "RunKeeper",
#    "total_distance": 3016.57855675634,
#    "duration": 3371,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 366,
#    "start_time": "Mon, 22 Feb 2016 06:09:37",
#    "uri": "/fitnessActivities/738351372",
#    "source": "RunKeeper",
#    "total_distance": 4815.5226769624,
#    "duration": 1797,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 353,
#    "start_time": "Mon, 15 Feb 2016 05:55:11",
#    "uri": "/fitnessActivities/734684880",
#    "source": "RunKeeper",
#    "total_distance": 4555.47243393235,
#    "duration": 1869,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -2,
#    "tracking_mode": "outdoor",
#    "total_calories": 238,
#    "start_time": "Wed, 4 Nov 2015 06:07:28",
#    "uri": "/fitnessActivities/695107893",
#    "source": "RunKeeper",
#    "total_distance": 3272.86475609347,
#    "duration": 1478,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -2,
#    "tracking_mode": "outdoor",
#    "total_calories": 357,
#    "start_time": "Tue, 27 Oct 2015 05:57:52",
#    "uri": "/fitnessActivities/682306939",
#    "source": "RunKeeper",
#    "total_distance": 4675.89620892755,
#    "duration": 1390,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 365,
#    "start_time": "Fri, 25 Sep 2015 06:03:30",
#    "uri": "/fitnessActivities/662964078",
#    "source": "RunKeeper",
#    "total_distance": 4683.06656215611,
#    "duration": 1358,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 361,
#    "start_time": "Tue, 22 Sep 2015 06:05:45",
#    "uri": "/fitnessActivities/660961272",
#    "source": "RunKeeper",
#    "total_distance": 4655.54963372923,
#    "duration": 1382,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 362,
#    "start_time": "Mon, 25 May 2015 05:40:07",
#    "uri": "/fitnessActivities/577596948",
#    "source": "RunKeeper",
#    "total_distance": 4703.8352331533,
#    "duration": 1458.45,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 360,
#    "start_time": "Thu, 30 Apr 2015 05:56:58",
#    "uri": "/fitnessActivities/559747998",
#    "source": "RunKeeper",
#    "total_distance": 4672.89007690554,
#    "duration": 1417.324,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 520,
#    "start_time": "Wed, 22 Apr 2015 05:53:43",
#    "uri": "/fitnessActivities/554014359",
#    "source": "RunKeeper",
#    "total_distance": 4690.98068548032,
#    "duration": 1397.167,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "Web",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 343,
#    "start_time": "Mon, 20 Apr 2015 05:40:00",
#    "uri": "/fitnessActivities/553679343",
#    "source": "RunKeeper",
#    "total_distance": 4498.63606169824,
#    "duration": 1500,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 130,
#    "start_time": "Sat, 15 Mar 2014 22:15:59",
#    "uri": "/fitnessActivities/439268589",
#    "source": "RunKeeper",
#    "total_distance": 1984.280937576,
#    "duration": 1436.981,
#    "type": "Running",
#    "has_path": true
#   },
#   {
#    "entry_mode": "API",
#    "utc_offset": -3,
#    "tracking_mode": "outdoor",
#    "total_calories": 65,
#    "start_time": "Sat, 15 Mar 2014 18:25:50",
#    "uri": "/fitnessActivities/439268582",
#    "source": "RunKeeper",
#    "total_distance": 986.246059611153,
#    "duration": 839.407,
#    "type": "Running",
#    "has_path": true
#   }
#  ],
#  "size": 585
# }

# %% [markdown]
# ## JSON to Data Frame conversion
#
# In order to have a better data manipulation, in the next cell we perform a conversion of importe in json format from API to pandas data frame

# %%
# Perform a conversion from JSON to Data Frame
api_df = json_normalize(api_content['items'])

# Converts the duration from seconds to minutes
api_df['duration'] = api_df['duration']/60
api_df['duration'] = api_df['duration'].round(2);

# Round the distance
api_df['total_distance'] = api_df['total_distance'].round(2);

api_df
# Out:
#      duration entry_mode  has_path     source                 start_time  \
# 0       37.87        API      True  RunKeeper  Fri, 26 Oct 2018 18:03:16
# 1       25.92        API      True  RunKeeper  Fri, 26 Oct 2018 07:56:50
# 2       18.72        API      True  RunKeeper  Wed, 24 Oct 2018 12:33:35
# 3       24.63        API      True  RunKeeper  Wed, 24 Oct 2018 07:22:57
# 4       20.37        API      True  RunKeeper  Tue, 23 Oct 2018 13:15:36
# 5       24.95        API      True  RunKeeper  Fri, 19 Oct 2018 07:30:10
# 6       33.05        API      True  RunKeeper  Wed, 17 Oct 2018 15:20:50
# 7       25.77        API      True  RunKeeper  Wed, 17 Oct 2018 07:58:51
# 8       41.90        API      True  RunKeeper   Tue, 9 Oct 2018 13:42:13
# 9       24.40        API      True  RunKeeper   Tue, 9 Oct 2018 07:01:20
# 10      50.15        API      True  RunKeeper   Fri, 5 Oct 2018 13:31:20
# 11      24.72        API      True  RunKeeper   Fri, 5 Oct 2018 07:32:10
# 12      34.13        API      True  RunKeeper   Tue, 2 Oct 2018 12:19:17
# 13      27.50        API      True  RunKeeper   Tue, 2 Oct 2018 07:10:18
# 14      55.52        API      True  RunKeeper  Thu, 27 Sep 2018 07:50:07
# 15      32.47        API      True  RunKeeper  Tue, 25 Sep 2018 12:24:03
# 16      23.60        API      True  RunKeeper  Tue, 25 Sep 2018 07:42:44
# 17      27.90        API      True  RunKeeper  Thu, 20 Sep 2018 13:24:59
# 18      25.97        API      True  RunKeeper  Thu, 20 Sep 2018 07:12:25
# 19      33.07        API      True  RunKeeper  Tue, 18 Sep 2018 12:54:14
# 20      25.38        API      True  RunKeeper  Tue, 18 Sep 2018 07:22:49
# 21      66.53        API      True  RunKeeper  Thu, 13 Sep 2018 14:03:45
# 22      24.87        API      True  RunKeeper  Thu, 13 Sep 2018 07:44:54
# 23      32.38        API      True  RunKeeper  Tue, 11 Sep 2018 13:36:48
# 24      25.77        API      True  RunKeeper  Tue, 11 Sep 2018 07:56:25
# 25      30.60        API      True  RunKeeper   Wed, 5 Sep 2018 12:59:40
# 26      25.02        API      True  RunKeeper   Wed, 5 Sep 2018 07:18:07
# 27      35.37        API      True  RunKeeper  Fri, 31 Aug 2018 13:46:10
# 28      23.97        API      True  RunKeeper  Fri, 31 Aug 2018 07:00:07
# 29      28.90        API      True  RunKeeper  Wed, 29 Aug 2018 13:05:19
# ..        ...        ...       ...        ...                        ...
# 555     30.62        API      True  RunKeeper  Wed, 20 Apr 2016 05:51:15
# 556      7.50        API      True  RunKeeper  Mon, 18 Apr 2016 06:19:21
# 557     26.43        API      True  RunKeeper  Mon, 18 Apr 2016 05:50:48
# 558     27.18        API      True  RunKeeper  Mon, 11 Apr 2016 05:23:04
# 559    133.97        API      True  RunKeeper   Thu, 7 Apr 2016 07:34:36
# 560     39.42        API      True  RunKeeper  Tue, 29 Mar 2016 05:38:59
# 561     27.33        API      True  RunKeeper  Wed, 23 Mar 2016 06:08:51
# 562     28.03        API      True  RunKeeper  Mon, 21 Mar 2016 05:57:29
# 563      4.35        API      True  RunKeeper  Sun, 20 Mar 2016 17:04:57
# 564     27.27        API      True  RunKeeper  Mon, 14 Mar 2016 05:52:20
# 565     14.98        API      True  RunKeeper   Tue, 8 Mar 2016 13:22:25
# 566     28.20        API      True  RunKeeper   Mon, 7 Mar 2016 06:03:09
# 567     58.43        API      True  RunKeeper   Sun, 6 Mar 2016 13:53:27
# 568     26.12        API      True  RunKeeper   Sun, 6 Mar 2016 11:23:33
# 569     30.35        API      True  RunKeeper   Thu, 3 Mar 2016 05:52:24
# 570     48.85        API      True  RunKeeper   Wed, 2 Mar 2016 18:26:34
# 571     31.95        API      True  RunKeeper  Mon, 29 Feb 2016 06:05:33
# 572     56.18        API      True  RunKeeper  Sun, 28 Feb 2016 10:41:56
# 573     29.95        API      True  RunKeeper  Mon, 22 Feb 2016 06:09:37
# 574     31.15        API      True  RunKeeper  Mon, 15 Feb 2016 05:55:11
# 575     24.63        API      True  RunKeeper   Wed, 4 Nov 2015 06:07:28
# 576     23.17        API      True  RunKeeper  Tue, 27 Oct 2015 05:57:52
# 577     22.63        API      True  RunKeeper  Fri, 25 Sep 2015 06:03:30
# 578     23.03        API      True  RunKeeper  Tue, 22 Sep 2015 06:05:45
# 579     24.31        API      True  RunKeeper  Mon, 25 May 2015 05:40:07
# 580     23.62        API      True  RunKeeper  Thu, 30 Apr 2015 05:56:58
# 581     23.29        API      True  RunKeeper  Wed, 22 Apr 2015 05:53:43
# 582     25.00        Web      True  RunKeeper  Mon, 20 Apr 2015 05:40:00
# 583     23.95        API      True  RunKeeper  Sat, 15 Mar 2014 22:15:59
# 584     13.99        API      True  RunKeeper  Sat, 15 Mar 2014 18:25:50
#
#      total_calories  total_distance tracking_mode     type  \
# 0               256         8151.83       outdoor  Cycling
# 1               193         7900.93       outdoor  Cycling
# 2               127         4127.19       outdoor  Cycling
# 3               201         7933.17       outdoor  Cycling
# 4               158         5281.13       outdoor  Cycling
# 5               203         7546.29       outdoor  Cycling
# 6               252         7992.05       outdoor  Cycling
# 7               196         7807.02       outdoor  Cycling
# 8               282         8791.48       outdoor  Cycling
# 9               195         7944.65       outdoor  Cycling
# 10              293         8646.50       outdoor  Cycling
# 11              198         7561.67       outdoor  Cycling
# 12              234         8010.35       outdoor  Cycling
# 13              215         7911.28       outdoor  Cycling
# 14              379        10472.91       outdoor  Cycling
# 15              230         7972.87       outdoor  Cycling
# 16              192         7530.85       outdoor  Cycling
# 17              204         7113.38       outdoor  Cycling
# 18              209         7935.36       outdoor  Cycling
# 19              236         7396.22       outdoor  Cycling
# 20              198         7976.80       outdoor  Cycling
# 21              504        19522.71       outdoor  Cycling
# 22              197         7961.16       outdoor  Cycling
# 23              228         8050.79       outdoor  Cycling
# 24              196         7964.82       outdoor  Cycling
# 25              227         7956.92       outdoor  Cycling
# 26              198         7934.99       outdoor  Cycling
# 27              247         8595.08       outdoor  Cycling
# 28              201         7890.32       outdoor  Cycling
# 29              205         7059.60       outdoor  Cycling
# ..              ...             ...           ...      ...
# 555             456         5734.59       outdoor  Running
# 556              63         1047.16       outdoor  Running
# 557             565         5782.77       outdoor  Running
# 558             458         5895.76       outdoor  Running
# 559             660         3698.49       outdoor  Running
# 560             435         5990.81       outdoor  Running
# 561             454         5749.38       outdoor  Running
# 562             455         5789.03       outdoor  Running
# 563              49          779.13       outdoor  Running
# 564             447         5674.95       outdoor  Running
# 565              75         1213.08       outdoor  Running
# 566             462         5838.99       outdoor  Running
# 567             253         3927.29       outdoor  Running
# 568             101         1593.61       outdoor  Running
# 569             489         6154.29       outdoor  Running
# 570             105          844.11       outdoor  Running
# 571             467         5805.84       outdoor  Running
# 572             205         3016.58       outdoor  Running
# 573             366         4815.52       outdoor  Running
# 574             353         4555.47       outdoor  Running
# 575             238         3272.86       outdoor  Running
# 576             357         4675.90       outdoor  Running
# 577             365         4683.07       outdoor  Running
# 578             361         4655.55       outdoor  Running
# 579             362         4703.84       outdoor  Running
# 580             360         4672.89       outdoor  Running
# 581             520         4690.98       outdoor  Running
# 582             343         4498.64       outdoor  Running
# 583             130         1984.28       outdoor  Running
# 584              65          986.25       outdoor  Running
#
#                                uri  utc_offset
# 0    /fitnessActivities/1248977291          -3
# 1    /fitnessActivities/1248977286          -3
# 2    /fitnessActivities/1247963081          -3
# 3    /fitnessActivities/1247963047          -3
# 4    /fitnessActivities/1247963042          -3
# 5    /fitnessActivities/1247963039          -3
# 6    /fitnessActivities/1247963036          -3
# 7    /fitnessActivities/1247963033          -3
# 8    /fitnessActivities/1241059614          -3
# 9    /fitnessActivities/1241059598          -3
# 10   /fitnessActivities/1239128443          -3
# 11   /fitnessActivities/1239108321          -3
# 12   /fitnessActivities/1237705303          -3
# 13   /fitnessActivities/1237576166          -3
# 14   /fitnessActivities/1237541305          -3
# 15   /fitnessActivities/1237541300          -3
# 16   /fitnessActivities/1237541296          -3
# 17   /fitnessActivities/1237541244          -3
# 18   /fitnessActivities/1232056305          -3
# 19   /fitnessActivities/1232056300          -3
# 20   /fitnessActivities/1232056296          -3
# 21   /fitnessActivities/1232056293          -3
# 22   /fitnessActivities/1232056068          -3
# 23   /fitnessActivities/1232056058          -3
# 24   /fitnessActivities/1232056039          -3
# 25   /fitnessActivities/1232056036          -3
# 26   /fitnessActivities/1232056028          -3
# 27   /fitnessActivities/1221821645          -3
# 28   /fitnessActivities/1221793323          -3
# 29   /fitnessActivities/1221793316          -3
# ..                             ...         ...
# 555   /fitnessActivities/772361130          -3
# 556   /fitnessActivities/770943625          -3
# 557   /fitnessActivities/770943610          -3
# 558   /fitnessActivities/766282546          -3
# 559   /fitnessActivities/764018100          -3
# 560   /fitnessActivities/759716642          -3
# 561   /fitnessActivities/755079850          -3
# 562   /fitnessActivities/753860205          -3
# 563   /fitnessActivities/753646484          -3
# 564   /fitnessActivities/749797852          -3
# 565   /fitnessActivities/747371294          -3
# 566   /fitnessActivities/745796497          -3
# 567   /fitnessActivities/745656183          -3
# 568   /fitnessActivities/745656175          -3
# 569   /fitnessActivities/743736231          -3
# 570   /fitnessActivities/743518140          -3
# 571   /fitnessActivities/742107339          -3
# 572   /fitnessActivities/742025830          -3
# 573   /fitnessActivities/738351372          -3
# 574   /fitnessActivities/734684880          -3
# 575   /fitnessActivities/695107893          -2
# 576   /fitnessActivities/682306939          -2
# 577   /fitnessActivities/662964078          -3
# 578   /fitnessActivities/660961272          -3
# 579   /fitnessActivities/577596948          -3
# 580   /fitnessActivities/559747998          -3
# 581   /fitnessActivities/554014359          -3
# 582   /fitnessActivities/553679343          -3
# 583   /fitnessActivities/439268589          -3
# 584   /fitnessActivities/439268582          -3
#
# [585 rows x 11 columns]

# %% [markdown]
# ## Data export [optional]
#
# In order to visualize the data into an excel file, the cell bellow is responsible for exporting the data.

# %%
# Export the new dataSet to csv
api_df.to_csv('dataSource.csv', encoding="utf-8")

# %% [markdown]
# <hr>

# %% [markdown]
# # II - Activites by period
#
# #### First of all we need to split the information by period. To achieve that, the idea is apply a group selection by partial string in timestamp column

# %% [markdown]
# ## Timestamp split into columns
#
# In order to have a better way to handle the data by period, it'll be necessary split the timestamp column into separate columns

# %%
# =================================================================================
# Dataframe timestamp split
# =================================================================================

# Copy the data
data_with_period = api_df.copy()
data_with_period["month"] = 0
data_with_period["month_index"] = 0
data_with_period["year"] = 0

# Fill the years
data_with_period.loc[data_with_period['start_time'].str.contains('2018'), 'year'] = '2018'
data_with_period.loc[data_with_period['start_time'].str.contains('2017'), 'year'] = '2017'
data_with_period.loc[data_with_period['start_time'].str.contains('2016'), 'year'] = '2016'
data_with_period.loc[data_with_period['start_time'].str.contains('2015'), 'year'] = '2015'
data_with_period.loc[data_with_period['start_time'].str.contains('2014'), 'year'] = '2014'

# Fill the months
data_with_period.loc[data_with_period['start_time'].str.contains('Jan'), 'month'] = 'Jan'
data_with_period.loc[data_with_period['start_time'].str.contains('Jan'), 'month_index'] = '1'

data_with_period.loc[data_with_period['start_time'].str.contains('Feb'), 'month'] = 'Feb'
data_with_period.loc[data_with_period['start_time'].str.contains('Feb'), 'month_index'] = '2'

data_with_period.loc[data_with_period['start_time'].str.contains('Mar'), 'month'] = 'Mar'
data_with_period.loc[data_with_period['start_time'].str.contains('Mar'), 'month_index'] = '3'

data_with_period.loc[data_with_period['start_time'].str.contains('Apr'), 'month'] = 'Apr'
data_with_period.loc[data_with_period['start_time'].str.contains('Apr'), 'month_index'] = '4'

data_with_period.loc[data_with_period['start_time'].str.contains('May'), 'month'] = 'May'
data_with_period.loc[data_with_period['start_time'].str.contains('May'), 'month_index'] = '5'

data_with_period.loc[data_with_period['start_time'].str.contains('Jun'), 'month'] = 'Jun'
data_with_period.loc[data_with_period['start_time'].str.contains('Jun'), 'month_index'] = '6'

data_with_period.loc[data_with_period['start_time'].str.contains('Jul'), 'month'] = 'Jul'
data_with_period.loc[data_with_period['start_time'].str.contains('Jul'), 'month_index'] = '7'

data_with_period.loc[data_with_period['start_time'].str.contains('Aug'), 'month'] = 'Aug'
data_with_period.loc[data_with_period['start_time'].str.contains('Aug'), 'month_index'] = '8'

data_with_period.loc[data_with_period['start_time'].str.contains('Sep'), 'month'] = 'Sep'
data_with_period.loc[data_with_period['start_time'].str.contains('Sep'), 'month_index'] = '9'

data_with_period.loc[data_with_period['start_time'].str.contains('Oct'), 'month'] = 'Oct'
data_with_period.loc[data_with_period['start_time'].str.contains('Oct'), 'month_index'] = '10'

data_with_period.loc[data_with_period['start_time'].str.contains('Nov'), 'month'] = 'Nov'
data_with_period.loc[data_with_period['start_time'].str.contains('Nov'), 'month_index'] = '11'

data_with_period.loc[data_with_period['start_time'].str.contains('Dec'), 'month'] = 'Dec'
data_with_period.loc[data_with_period['start_time'].str.contains('Dec'), 'month_index'] = '12'

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid replacing the timestamp to other columns, we'll export the new dataSet to a csv file. You can skip this operation because the new .csv dataSet is already included in the project

# %%
# Export the new dataSet to csv
data_with_period.to_csv('dataSourceByPeriod.csv', encoding="utf-8")

# %% [markdown]
# ## Filter the period [optional]

# %%
# Filter param
year = '2017'

# Copy the data with timestamp splitted
data_filter = data_with_period.copy()

# Perform the filter
data_filter = data_filter[data_filter['year'] == year]

# Export the new dataSet to csv
data_filter.to_csv('dataSourceByPeriod' + year + '.csv', encoding="utf-8")

# %% [markdown]
# <hr>

# %% [markdown]
# # III - Geolocation section
#
# #### Here in this section, we'll handle the geolocation infos.

# %% [markdown]
# ## Geolocation data import [warning: too heavy]
#
# The cell below perform multiple requests to Runkeep Health Graph API, in order to retrieve all activities in details to get location informations such as: latitude/longitude

# %%
# =================================================================================
# Geolocation data
# =================================================================================

# Copy the data
geolocation_data = pd.DataFrame()

# =================================================================================
# API single activity request
# =================================================================================

from itertools import islice

# Base URI
base_URI = "http://api.runkeeper.com"

# Loop parameters
start = 399
stop = 498
step = 1

# Run through all activites
for idx, row in islice(data_with_period.iterrows(), start, stop, step):
    # Final activity URI
    activity_url = base_URI + row['uri'] + "?access_token=" + ACCESS_TOKEN

    # Receive the results from API
    activity_content = requests.get(activity_url).json()

    # Perform a conversion from JSON to Data Frame
    if 'path' in activity_content:
        activity_df = json_normalize(activity_content['path'])
        activity_df['datetime'] = row['start_time']
        activity_df['year'] = row['year']
        activity_df['month'] = row['month_index']
    elif 'limit' in activity_content:
        # Reach the API limit (need to wait)
        print('The API reached the 15 minutes limit')
        break
    
    # Add the activity path data to geolocation
    geolocation_data = pd.concat([geolocation_data, activity_df])
    
geolocation_data
# Out:
#       altitude  latitude  longitude  timestamp   type  \
# 0    33.500000 -5.868115 -35.188564      0.000  start
# 1    33.571429 -5.868137 -35.188480     44.639    gps
# 2    33.625000 -5.868227 -35.188417     48.640    gps
# 3    33.666667 -5.868263 -35.188324     51.647    gps
# 4    33.700000 -5.868335 -35.188240     54.648    gps
# 5    33.727273 -5.868400 -35.188152     57.639    gps
# 6    33.818182 -5.868477 -35.188068     60.634    gps
# 7    33.909091 -5.868551 -35.187980     63.643    gps
# 8    34.000000 -5.868574 -35.187879     66.644    gps
# 9    34.000000 -5.868543 -35.187795     69.635    gps
# 10   34.000000 -5.868471 -35.187717     72.638    gps
# 11   34.000000 -5.868397 -35.187647     75.645    gps
# 12   33.909091 -5.868301 -35.187587     78.636    gps
# 13   33.818182 -5.868202 -35.187521     81.641    gps
# 14   33.727273 -5.868146 -35.187454     83.642    gps
# 15   33.636364 -5.868051 -35.187383     86.647    gps
# 16   33.545455 -5.867959 -35.187307     89.636    gps
# 17   33.363636 -5.867890 -35.187257     91.638    gps
# 18   33.181818 -5.867811 -35.187212     93.641    gps
# 19   33.090909 -5.867739 -35.187165     95.635    gps
# 20   33.090909 -5.867674 -35.187111     97.639    gps
# 21   33.181818 -5.867591 -35.187060     99.642    gps
# 22   33.363636 -5.867519 -35.187007    101.644    gps
# 23   33.727273 -5.867447 -35.186946    103.640    gps
# 24   34.181818 -5.867369 -35.186882    105.639    gps
# 25   34.636364 -5.867284 -35.186825    107.650    gps
# 26   35.000000 -5.867199 -35.186754    109.640    gps
# 27   35.363636 -5.867115 -35.186685    111.645    gps
# 28   35.727273 -5.867035 -35.186617    113.705    gps
# 29   36.181818 -5.866951 -35.186557    115.714    gps
# ..         ...       ...        ...        ...    ...
# 109  51.727273 -5.850723 -35.205535    835.595    gps
# 110  51.636364 -5.850759 -35.205453    840.595    gps
# 111  51.545455 -5.850820 -35.205382    847.593    gps
# 112  51.454545 -5.850872 -35.205310    855.630    gps
# 113  51.454545 -5.850918 -35.205238    861.612    gps
# 114  51.454545 -5.850993 -35.205168    866.623    gps
# 115  51.454545 -5.851028 -35.205069    879.594    gps
# 116  51.454545 -5.851087 -35.205005    884.594    gps
# 117  51.454545 -5.851137 -35.204931    894.595    gps
# 118  51.545455 -5.851209 -35.204895    897.599    gps
# 119  51.454545 -5.851305 -35.204824    902.594    gps
# 120  51.363636 -5.851373 -35.204768    909.593    gps
# 121  51.272727 -5.851415 -35.204695    915.596    gps
# 122  51.181818 -5.851450 -35.204620    921.602    gps
# 123  51.090909 -5.851506 -35.204546    927.590    gps
# 124  50.909091 -5.851552 -35.204476    932.601    gps
# 125  50.727273 -5.851560 -35.204391    941.600    gps
# 126  50.545455 -5.851617 -35.204324    948.592    gps
# 127  50.363636 -5.851653 -35.204246    956.593    gps
# 128  50.181818 -5.851719 -35.204179    960.589    gps
# 129  50.000000 -5.851808 -35.204096    964.600    gps
# 130  49.909091 -5.851821 -35.204006    975.591    gps
# 131  49.818182 -5.851881 -35.203937    982.590    gps
# 132  49.727273 -5.851928 -35.203859    989.594    gps
# 133  49.636364 -5.851984 -35.203797   1036.592    gps
# 134  49.600000 -5.852041 -35.203729   1049.592    gps
# 135  49.555556 -5.852123 -35.203678   1055.594    gps
# 136  49.500000 -5.852182 -35.203621   1060.653    gps
# 137  49.428571 -5.852254 -35.203575   1065.647    gps
# 138  49.333333 -5.852254 -35.203575   1065.648    end
#
#                       datetime  year month
# 0    Thu, 11 May 2017 12:17:38  2017     5
# 1    Thu, 11 May 2017 12:17:38  2017     5
# 2    Thu, 11 May 2017 12:17:38  2017     5
# 3    Thu, 11 May 2017 12:17:38  2017     5
# 4    Thu, 11 May 2017 12:17:38  2017     5
# 5    Thu, 11 May 2017 12:17:38  2017     5
# 6    Thu, 11 May 2017 12:17:38  2017     5
# 7    Thu, 11 May 2017 12:17:38  2017     5
# 8    Thu, 11 May 2017 12:17:38  2017     5
# 9    Thu, 11 May 2017 12:17:38  2017     5
# 10   Thu, 11 May 2017 12:17:38  2017     5
# 11   Thu, 11 May 2017 12:17:38  2017     5
# 12   Thu, 11 May 2017 12:17:38  2017     5
# 13   Thu, 11 May 2017 12:17:38  2017     5
# 14   Thu, 11 May 2017 12:17:38  2017     5
# 15   Thu, 11 May 2017 12:17:38  2017     5
# 16   Thu, 11 May 2017 12:17:38  2017     5
# 17   Thu, 11 May 2017 12:17:38  2017     5
# 18   Thu, 11 May 2017 12:17:38  2017     5
# 19   Thu, 11 May 2017 12:17:38  2017     5
# 20   Thu, 11 May 2017 12:17:38  2017     5
# 21   Thu, 11 May 2017 12:17:38  2017     5
# 22   Thu, 11 May 2017 12:17:38  2017     5
# 23   Thu, 11 May 2017 12:17:38  2017     5
# 24   Thu, 11 May 2017 12:17:38  2017     5
# 25   Thu, 11 May 2017 12:17:38  2017     5
# 26   Thu, 11 May 2017 12:17:38  2017     5
# 27   Thu, 11 May 2017 12:17:38  2017     5
# 28   Thu, 11 May 2017 12:17:38  2017     5
# 29   Thu, 11 May 2017 12:17:38  2017     5
# ..                         ...   ...   ...
# 109  Wed, 23 Nov 2016 13:23:34  2016    11
# 110  Wed, 23 Nov 2016 13:23:34  2016    11
# 111  Wed, 23 Nov 2016 13:23:34  2016    11
# 112  Wed, 23 Nov 2016 13:23:34  2016    11
# 113  Wed, 23 Nov 2016 13:23:34  2016    11
# 114  Wed, 23 Nov 2016 13:23:34  2016    11
# 115  Wed, 23 Nov 2016 13:23:34  2016    11
# 116  Wed, 23 Nov 2016 13:23:34  2016    11
# 117  Wed, 23 Nov 2016 13:23:34  2016    11
# 118  Wed, 23 Nov 2016 13:23:34  2016    11
# 119  Wed, 23 Nov 2016 13:23:34  2016    11
# 120  Wed, 23 Nov 2016 13:23:34  2016    11
# 121  Wed, 23 Nov 2016 13:23:34  2016    11
# 122  Wed, 23 Nov 2016 13:23:34  2016    11
# 123  Wed, 23 Nov 2016 13:23:34  2016    11
# 124  Wed, 23 Nov 2016 13:23:34  2016    11
# 125  Wed, 23 Nov 2016 13:23:34  2016    11
# 126  Wed, 23 Nov 2016 13:23:34  2016    11
# 127  Wed, 23 Nov 2016 13:23:34  2016    11
# 128  Wed, 23 Nov 2016 13:23:34  2016    11
# 129  Wed, 23 Nov 2016 13:23:34  2016    11
# 130  Wed, 23 Nov 2016 13:23:34  2016    11
# 131  Wed, 23 Nov 2016 13:23:34  2016    11
# 132  Wed, 23 Nov 2016 13:23:34  2016    11
# 133  Wed, 23 Nov 2016 13:23:34  2016    11
# 134  Wed, 23 Nov 2016 13:23:34  2016    11
# 135  Wed, 23 Nov 2016 13:23:34  2016    11
# 136  Wed, 23 Nov 2016 13:23:34  2016    11
# 137  Wed, 23 Nov 2016 13:23:34  2016    11
# 138  Wed, 23 Nov 2016 13:23:34  2016    11
#
# [42428 rows x 8 columns]

# %% [markdown]
# ## Geolocation data import by period [less heavy]
#
# #### Note: Execute the dataSet filter first
#
# The cell below perform multiple requests to Runkeep Health Graph API, in order to retrieve all activities in details to get location informations such as: latitude/longitude

# %%
# =================================================================================
# Geolocation data
# =================================================================================

# Copy the data
geolocation_data = pd.DataFrame()

# =================================================================================
# API single activity request
# =================================================================================

# Base URI
base_URI = "http://api.runkeeper.com"

# Run through filtered activities
for idx, row in tqdm(data_filter.iterrows()):
    
    # Final activity URI
    activity_url = base_URI + row['uri'] + "?access_token=" + ACCESS_TOKEN

    # Receive the results from API
    activity_content = requests.get(activity_url).json()

    # Perform a conversion from JSON to Data Frame
    if 'path' in activity_content:
        activity_df = None
        activity_df = json_normalize(activity_content['path'])
        activity_df['datetime'] = row['start_time']
        activity_df['year'] = row['year']
        activity_df['month'] = row['month_index']

    # Add the activity path data to geolocation
    geolocation_data = pd.concat([geolocation_data, activity_df])
    
geolocation_data

# %% [markdown]
# ## Data export [optional]
#
# In order to avoid processing the cell above, here we are saving the processed geolocationd data.

# %%
# Export the new dataSet to csv
geolocation_data.to_csv('geolocation005.csv', encoding="utf-8")

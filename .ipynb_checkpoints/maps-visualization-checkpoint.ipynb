# %% [markdown]
# # Programming Project - Unit 2
# *by Débora Azevedo, Eliseu Jayro, Francisco de Paiva and Igor Brandão*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Geolocation analysis and hypotheses should be explained in detail;

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - Geocoding;
# - Maps;
# - File input;
# - Heatmap;
# - Numpy library;
# - Tqdm progress bar

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# !pip install tabulate
# !pip install pandas-datareader

# %%
# Import pandas
import pandas as pd

# Import google geocoder
import geocoder as gc

# Import numpy library
import numpy as np

# Import folium maps
import os
import folium
from folium import plugins

# Import tqdm progressing bar plugin
from tqdm import tqdm

# %% [markdown]
# <hr>

# %% [markdown]
# # I - Maps section

# %% [markdown]
# ## Geolocation data import [optional]

# %%
# Import the fertility.csv data: data
geolocation_data = pd.read_csv("geolocation.csv", encoding = 'latin2')

# %% [markdown]
# ### Coordinate groupping
#
# The cell below perform the latitude/longitude reading and count all og them to know if there are repetitions and group *[latitude, longitude, count]* data into the coordinate array

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Add the coordinates
# =================================================================================

# Initialize the coordinates array
coordinates = []

# Add the coordinates to the coordinate
for i in tqdm(range(len(geodata))):
    # eliminate items with'nan' element
    if all(~np.isnan([geodata.loc[geodata.index[i],'latitude'], geodata.loc[geodata.index[i],'longitude'], geodata.loc[geodata.index[i],'count']])):
        coordinates.append([geodata.loc[geodata.index[i],'latitude'], geodata.loc[geodata.index[i],'longitude'], geodata.loc[geodata.index[i],'count']])

# Display the imported coordinates
coordinates
# Out:
# 100%|██████████| 66057/66057 [00:12<00:00, 5422.05it/s]
# [[-5.833464, -35.218281, 1],
#  [-5.833383, -35.218238, 1],
#  [-5.833541, -35.218231, 1],
#  [-5.833565, -35.21823, 1],
#  [-5.83355, -35.218205, 1],
#  [-5.8334660000000005, -35.218205, 1],
#  [-5.833451, -35.218205, 1],
#  [-5.833361, -35.218205, 1],
#  [-5.833295, -35.218203, 1],
#  [-5.8333900000000005, -35.218176, 1],
#  [-5.833198, -35.218166, 1],
#  [-5.833258, -35.218158, 1],
#  [-5.833595, -35.21815, 1],
#  [-5.833311, -35.218148, 1],
#  [-5.833546, -35.218140000000005, 1],
#  [-5.83309, -35.218138, 1],
#  [-5.833578, -35.218118, 1],
#  [-5.833229, -35.218115000000004, 1],
#  [-5.833183, -35.218106, 1],
#  [-5.833464, -35.218098, 1],
#  [-5.833666, -35.218096, 1],
#  [-5.8329830000000005, -35.218088, 1],
#  [-5.833146, -35.218076, 1],
#  [-5.833106, -35.218076, 1],
#  [-5.833501, -35.218061, 1],
#  [-5.833368, -35.218059999999994, 1],
#  [-5.833028, -35.21805, 1],
#  [-5.833053, -35.218038, 1],
#  [-5.83288, -35.218033, 1],
#  [-5.83329, -35.218025, 1],
#  [-5.832949, -35.21802, 1],
#  [-5.833394, -35.218018, 1],
#  [-5.833725, -35.218001, 1],
#  [-5.832953, -35.218, 1],
#  [-5.832801, -35.217998, 1],
#  [-5.832835, -35.217988, 1],
#  [-5.832861, -35.217976, 1],
#  [-5.833296, -35.21797, 1],
#  [-5.832756, -35.217966, 1],
#  [-5.832769, -35.217965, 1],
#  [-5.832721, -35.21796, 1],
#  [-5.832655, -35.217940999999996, 1],
#  [-5.832678, -35.217938000000004, 1],
#  [-5.833235, -35.217935, 1],
#  [-5.832643, -35.217926, 1],
#  [-5.833756, -35.217925, 1],
#  [-5.833241, -35.21792, 1],
#  [-5.833173, -35.217915999999995, 1],
#  [-5.83321, -35.217913, 1],
#  [-5.83315, -35.217913, 1],
#  [-5.833266, -35.217911, 1],
#  [-5.833143, -35.217911, 1],
#  [-5.833138, -35.217909000000006, 1],
#  [-5.833175, -35.217908, 1],
#  [-5.8331349999999995, -35.217906, 1],
#  [-5.8326, -35.217906, 1],
#  [-5.833236, -35.217901, 1],
#  [-5.833181, -35.2179, 1],
#  [-5.832545, -35.2179, 1],
#  [-5.8332559999999996, -35.217895, 1],
#  [-5.83327, -35.217890999999995, 1],
#  [-5.832558000000001, -35.217890999999995, 1],
#  [-5.833283, -35.217890000000004, 1],
#  [-5.833076, -35.217890000000004, 1],
#  [-5.833203, -35.217883, 1],
#  [-5.833238, -35.21788, 1],
#  [-5.833048000000001, -35.217878000000006, 1],
#  [-5.833098000000001, -35.217875, 1],
#  [-5.83303, -35.217873, 1],
#  [-5.83252, -35.217873, 1],
#  [-5.83324, -35.21787, 480],
#  [-5.833069, -35.21787, 1],
#  [-5.833086, -35.217868, 1],
#  [-5.8330459999999995, -35.217868, 1],
#  [-5.833028, -35.217864, 1],
#  [-5.832463, -35.217864, 1],
#  [-5.832466, -35.217861, 1],
#  [-5.833285, -35.217859999999995, 1],
#  [-5.832979, -35.217859999999995, 1],
#  [-5.8331349999999995, -35.217855, 480],
#  [-5.833248, -35.217853000000005, 1],
#  [-5.83328, -35.217851, 1],
#  [-5.833021, -35.217846, 1],
#  [-5.83309, -35.217843, 1],
#  [-5.832979, -35.21784, 1],
#  [-5.832378, -35.217838, 1],
#  [-5.832979, -35.217836, 1],
#  [-5.83294, -35.217836, 1],
#  [-5.833276000000001, -35.217835, 1],
#  [-5.833261, -35.217835, 1],
#  [-5.83293, -35.217835, 1],
#  [-5.832953, -35.217833, 1],
#  [-5.832949, -35.217833, 1],
#  [-5.832403, -35.21783, 1],
#  [-5.83329, -35.217828000000004, 1],
#  [-5.832371, -35.217826, 1],
#  [-5.833803, -35.217821, 1],
#  [-5.832875, -35.217819, 1],
#  [-5.833033, -35.217818, 480],
#  [-5.8329379999999995, -35.217813, 1],
#  [-5.83327, -35.217811, 1],
#  [-5.833293, -35.21781, 1],
#  [-5.8333260000000005, -35.217806, 1],
#  [-5.829073, -35.217806, 1],
#  [-5.828991, -35.217805, 1],
#  [-5.832991000000001, -35.217803, 1],
#  [-5.832863, -35.217801, 1],
#  [-5.832294, -35.217801, 1],
#  [-5.832876000000001, -35.2178, 1],
#  [-5.828908, -35.2178, 1],
#  [-5.832829, -35.217797999999995, 1],
#  [-5.829155999999999, -35.217797999999995, 1],
#  [-5.83327, -35.217796, 1],
#  [-5.832856, -35.217796, 1],
#  [-5.8333010000000005, -35.217795, 1],
#  [-5.828823000000001, -35.217795, 1],
#  [-5.832813, -35.217793, 1],
#  [-5.832281, -35.217791, 1],
#  [-5.832848, -35.217786, 1],
#  [-5.832856, -35.217783000000004, 1],
#  [-5.828733000000001, -35.217783000000004, 1],
#  [-5.83328, -35.217781, 480],
#  [-5.832761, -35.217781, 1],
#  [-5.82924, -35.217781, 1],
#  [-5.828881, -35.21778, 1],
#  [-5.832301, -35.217776, 1],
#  [-5.832923, -35.217774, 480],
#  [-5.828786, -35.217774, 1],
#  [-5.8333129999999995, -35.217773, 1],
#  [-5.828976, -35.217771, 1],
#  [-5.8327860000000005, -35.217768, 1],
#  [-5.832708, -35.217766, 1],
#  [-5.828993, -35.217766, 1],
#  [-5.828886, -35.217765, 1],
#  [-5.833286, -35.217763, 1],
#  [-5.829098, -35.217763, 1],
#  [-5.832766, -35.217760999999996, 1],
#  [-5.829088, -35.217760999999996, 1],
#  [-5.832888, -35.21776, 1],
#  [-5.832763, -35.21776, 1],
#  [-5.8293230000000005, -35.21776, 1],
#  [-5.828698, -35.21776, 1],
#  [-5.832191000000001, -35.217758, 1],
#  [-5.828776, -35.217758, 1],
#  [-5.832183000000001, -35.217755, 1],
#  [-5.832724, -35.217753, 1],
#  [-5.833321, -35.217751, 1],
#  [-5.828618, -35.217751, 1],
#  [-5.833325, -35.21775, 1],
#  [-5.833304, -35.21775, 1],
#  [-5.833298, -35.21775, 1],
#  [-5.829199, -35.217748, 1],
#  [-5.832681, -35.217746000000005, 1],
#  [-5.828611, -35.217746000000005, 1],
#  [-5.832741, -35.217743, 1],
#  [-5.829191000000001, -35.217743, 1],
#  [-5.82866, -35.217743, 1],
#  [-5.832224, -35.217741, 1],
#  [-5.832648000000001, -35.217738, 1],
#  [-5.832696, -35.217736, 1],
#  [-5.829405, -35.217733, 1],
#  [-5.832803, -35.217729, 480],
#  [-5.832086, -35.217729, 1],
#  [-5.829301, -35.217729, 1],
#  [-5.832681, -35.217728, 1],
#  [-5.832578, -35.217728, 1],
#  [-5.828533, -35.217726, 1],
#  [-5.833321, -35.217725, 1],
#  [-5.832776, -35.217723, 1],
#  [-5.828523000000001, -35.217723, 1],
#  [-5.83211, -35.21772, 1],
#  [-5.832649, -35.217718, 1],
#  [-5.8293099999999995, -35.217715999999996, 1],
#  [-5.828545, -35.217713, 1],
#  [-5.83331, -35.217711, 1],
#  [-5.833846, -35.21771, 1],
#  [-5.8333010000000005, -35.217708, 1],
#  [-5.832576, -35.217708, 1],
#  [-5.8333129999999995, -35.217705, 480],
#  [-5.832115, -35.217705, 1],
#  [-5.833375, -35.217703, 1],
#  [-5.832593, -35.217703, 1],
#  [-5.8294, -35.217701, 1],
#  [-5.829524, -35.217698, 1],
#  [-5.832621, -35.217696000000004, 1],
#  [-5.82845, -35.217696000000004, 1],
#  [-5.832585, -35.217695, 1],
#  [-5.832541, -35.217695, 1],
#  [-5.831986, -35.217695, 1],
#  [-5.829403, -35.217695, 1],
#  [-5.828431, -35.217693, 1],
#  [-5.833341000000001, -35.217690000000005, 1],
#  [-5.832521, -35.217690000000005, 1],
#  [-5.832026, -35.217686, 1],
#  [-5.833318, -35.217684000000006, 1],
#  [-5.833351, -35.217683, 1],
#  [-5.832656, -35.217683, 1],
#  [-5.832676, -35.217681, 480],
#  [-5.828428, -35.21768, 1],
#  [-5.832528, -35.217676000000004, 1],
#  [-5.832031, -35.217676000000004, 1],
#  [-5.832508, -35.217675, 1],
#  [-5.832436, -35.217667999999996, 1],
#  [-5.829496, -35.217667999999996, 1],
#  [-5.829493, -35.217667999999996, 1],
#  [-5.833356, -35.217665999999994, 1],
#  [-5.828361, -35.217665999999994, 1],
#  [-5.832438, -35.217665000000004, 1],
#  [-5.829608, -35.217665000000004, 1],
#  [-5.833355, -35.217661, 1],
#  [-5.832491, -35.217661, 1],
#  [-5.828339, -35.217658, 1],
#  [-5.833335, -35.217656, 1],
#  [-5.831881, -35.217656, 1],
#  [-5.833336, -35.217655, 1],
#  [-5.831938, -35.217651000000004, 1],
#  [-5.8325, -35.21765, 1],
#  [-5.8319529999999995, -35.217645000000005, 1],
#  [-5.832391, -35.217643, 1],
#  [-5.8333580000000005, -35.217639, 1],
#  [-5.832395, -35.217639, 1],
#  [-5.829581, -35.217639, 1],
#  [-5.832536, -35.217638, 1],
#  [-5.828308, -35.217638, 1],
#  [-5.83242, -35.217634999999994, 1],
#  [-5.832406, -35.217634999999994, 1],
#  [-5.829593, -35.217634999999994, 1],
#  [-5.8282680000000004, -35.217633, 1],
#  [-5.832545, -35.21763, 480],
#  [-5.829691, -35.217628000000005, 1],
#  [-5.832363, -35.217626, 1],
#  [-5.8338790000000005, -35.217625, 1],
#  [-5.833341000000001, -35.217625, 1],
#  [-5.832393, -35.217625, 1],
#  [-5.833345, -35.217621, 480],
#  [-5.828251, -35.217620000000004, 1],
#  [-5.832305, -35.217618, 1],
#  [-5.831876, -35.217615, 1],
#  [-5.831853, -35.217613, 1],
#  [-5.83177, -35.217613, 1],
#  [-5.833404, -35.217611, 1],
#  [-5.8333580000000005, -35.217611, 1],
#  [-5.829676, -35.21761, 1],
#  [-5.833336, -35.217608, 1],
#  [-5.832375, -35.2176, 1],
#  [-5.829688, -35.2176, 1],
#  [-5.833385, -35.217597999999995, 1],
#  [-5.832313, -35.217597999999995, 1],
#  [-5.832261, -35.217596, 1],
#  [-5.829768, -35.217593, 1],
#  [-5.828901, -35.217593, 1],
#  [-5.828178, -35.217593, 1],
#  [-5.833381, -35.21759, 1],
#  [-5.832416, -35.21759, 1],
#  [-5.832288, -35.21759, 2],
#  [-5.829013, -35.21759, 1],
#  [-5.828793, -35.217586, 1],
#  [-5.828191, -35.217583000000005, 1],
#  [-5.832249, -35.217581, 1],
#  [-5.833376, -35.21758, 1],
#  [-5.832409999999999, -35.21758, 480],
#  [-5.832291000000001, -35.21758, 1],
#  [-5.828933999999999, -35.21758, 1],
#  [-5.828163, -35.21758, 1],
#  [-5.833391000000001, -35.217578, 1],
#  [-5.829035, -35.217578, 1],
#  [-5.833368, -35.217576, 1],
#  [-5.829124, -35.217576, 1],
#  [-5.82868, -35.217576, 1],
#  [-5.833371, -35.217575, 1],
#  [-5.831765, -35.217575, 1],
#  [-5.828836, -35.217575, 1],
#  [-5.82977, -35.217571, 1],
#  [-5.828958, -35.217571, 1],
#  [-5.831745, -35.21757, 1],
#  [-5.828856, -35.21757, 1],
#  [-5.832168, -35.217568, 1],
#  [-5.829139, -35.217568, 1],
#  [-5.831681, -35.217566, 1],
#  [-5.828883, -35.217566, 1],
#  [-5.82906, -35.217565, 1],
#  [-5.828984999999999, -35.217565, 1],
#  [-5.829778, -35.217563, 1],
#  [-5.828881, -35.217563, 1],
#  [-5.828739, -35.217563, 1],
#  [-5.828981, -35.217560999999996, 1],
#  [-5.828901, -35.217560999999996, 1],
#  [-5.828780999999999, -35.21756, 1],
#  [-5.828753, -35.21756, 1],
#  [-5.832256, -35.217558000000004, 1],
#  [-5.829845, -35.217558000000004, 1],
#  [-5.829236, -35.217558000000004, 1],
#  [-5.832201, -35.217556, 1],
#  [-5.829086, -35.217556, 1],
#  [-5.829005, -35.217556, 1],
#  [-5.828798, -35.217556, 1],
#  [-5.828778, -35.217556, 1],
#  [-5.828571, -35.217555, 1],
#  [-5.829165, -35.217553, 1],
#  [-5.829088, -35.217553, 1],
#  [-5.828880000000001, -35.217553, 1],
#  [-5.829243, -35.217551, 1],
#  [-5.828876, -35.217551, 1],
#  [-5.833401, -35.217549, 1],
#  [-5.828976, -35.217549, 1],
#  [-5.82809, -35.217549, 1],
#  [-5.8321760000000005, -35.217548, 1],
#  [-5.828773, -35.217548, 1],
#  [-5.832294, -35.217546, 1],
#  [-5.82878, -35.217546, 1],
#  [-5.82868, -35.217546, 1],
#  [-5.828653, -35.217546, 1],
#  [-5.829111, -35.217545, 1],
#  [-5.828991, -35.217545, 1],
#  [-5.828646, -35.217545, 1],
#  [-5.8316550000000005, -35.217543, 1],
#  [-5.8287, -35.217543, 1],
#  [-5.8333699999999995, -35.217541, 1],
#  [-5.831676, -35.217541, 1],
#  [-5.8291949999999995, -35.217541, 1],
#  [-5.8291900000000005, -35.217541, 1],
#  [-5.829078, -35.217541, 1],
#  [-5.828676000000001, -35.217541, 1],
#  [-5.833911, -35.21754, 1],
#  [-5.833368, -35.21754, 480],
#  [-5.832183000000001, -35.21754, 1],
#  [-5.828916, -35.21754, 1],
#  [-5.832118, -35.217538, 1],
#  [-5.828811, -35.217538, 1],
#  [-5.828076, -35.217535999999996, 1],
#  [-5.8333900000000005, -35.217535, 1],
#  [-5.829025, -35.217535, 1],
#  [-5.828685, -35.217535, 1],
#  [-5.828668, -35.217535, 1],
#  [-5.831595, -35.217533, 1],
#  [-5.829269999999999, -35.217533, 1],
#  [-5.829858, -35.217531, 1],
#  [-5.829105, -35.217531, 1],
#  [-5.832269, -35.21753, 480],
#  [-5.82897, -35.21753, 480],
#  [-5.829351, -35.217528, 1],
#  [-5.829219, -35.217528, 1],
#  [-5.8291830000000004, -35.217528, 1],
#  [-5.828863, -35.217528, 480],
#  [-5.828708, -35.217528, 1],
#  [-5.8285800000000005, -35.217528, 1],
#  [-5.829346, -35.217526, 1],
#  [-5.828466000000001, -35.217526, 1],
#  [-5.832141, -35.217525, 1],
#  [-5.829863, -35.217525, 1],
#  [-5.82908, -35.217525, 480],
#  [-5.828601, -35.217525, 1],
#  [-5.828553, -35.217525, 1],
#  [-5.828551, -35.217525, 1],
#  [-5.832138, -35.217523, 1],
#  [-5.832101000000001, -35.217523, 1],
#  [-5.8292980000000005, -35.217523, 1],
#  [-5.829133000000001, -35.217523, 1],
#  [-5.828578, -35.217523, 1],
#  [-5.828081, -35.217523, 1],
#  [-5.829926, -35.21752, 1],
#  [-5.829293, -35.21752, 1],
#  [-5.83341, -35.217518, 1],
#  [-5.832023, -35.217518, 1],
#  [-5.832086, -35.217515999999996, 1],
#  [-5.8287580000000005, -35.217515999999996, 480],
#  [-5.828593, -35.217515999999996, 1],
#  [-5.829218, -35.217513000000004, 1],
#  [-5.828563, -35.217513000000004, 1],
#  [-5.829191000000001, -35.217511, 480],
#  [-5.828608, -35.217511, 1],
#  [-5.8333699999999995, -35.21751, 1],
#  [-5.832065, -35.21751, 1],
#  [-5.8315779999999995, -35.21751, 1],
#  [-5.831563, -35.21751, 1],
#  [-5.833418, -35.217508, 1],
#  [-5.829376, -35.217506, 1],
#  [-5.829288, -35.217504, 1],
#  [-5.829328, -35.217503, 1],
#  [-5.829241000000001, -35.217503, 1],
#  [-5.828485, -35.217503, 1],
#  [-5.828005999999999, -35.217503, 1],
#  [-5.83217, -35.217501, 1],
#  [-5.828506, -35.217501, 1],
#  [-5.832075, -35.2175, 1],
#  [-5.828656, -35.2175, 480],
#  [-5.828485, -35.2175, 1],
#  [-5.833403, -35.217498, 1],
#  [-5.828463, -35.217496000000004, 1],
#  [-5.828455, -35.217496000000004, 1],
#  [-5.833404, -35.217495, 1],
#  [-5.832025, -35.217495, 1],
#  [-5.831498000000001, -35.217495, 1],
#  [-5.833396, -35.217493, 1],
#  [-5.829406, -35.217493, 1],
#  [-5.828505000000001, -35.217493, 1],
#  [-5.828366, -35.217493, 1],
#  [-5.8334209999999995, -35.217490999999995, 1],
#  [-5.829943, -35.217490999999995, 1],
#  [-5.829465, -35.217490999999995, 1],
#  [-5.829451000000001, -35.217490999999995, 1],
#  [-5.829395, -35.217490999999995, 1],
#  [-5.827991, -35.217490000000005, 1],
#  [-5.829333, -35.217488, 1],
#  [-5.829306, -35.217488, 480],
#  [-5.828513, -35.217488, 1],
#  [-5.829944, -35.217486, 1],
#  [-5.82846, -35.217486, 1],
#  [-5.833426, -35.217483, 1],
#  [-5.8319730000000005, -35.217483, 1],
#  [-5.831501, -35.217483, 1],
#  [-5.832021, -35.217481, 1],
#  [-5.831468, -35.217481, 1],
#  [-5.83001, -35.217481, 1],
#  [-5.832134, -35.217478, 480],
#  [-5.831996, -35.217476, 1],
#  [-5.829353, -35.217475, 1],
#  [-5.8285599999999995, -35.217475, 480],
#  [-5.82944, -35.217473, 1],
#  [-5.829395, -35.217473, 1],
#  [-5.831965, -35.217471, 1],
#  [-5.829483, -35.217471, 1],
#  [-5.828415000000001, -35.217471, 1],
#  [-5.828393, -35.217471, 1],
#  [-5.82839, -35.217471, 1],
#  [-5.831881, -35.217468, 1],
#  [-5.82836, -35.217468, 1],
#  [-5.831948000000001, -35.217465999999995, 1],
#  [-5.831944999999999, -35.217465000000004, 1],
#  [-5.828418, -35.217465000000004, 1],
#  [-5.828374, -35.217465000000004, 1],
#  [-5.833404, -35.217463, 1],
#  [-5.831421, -35.217463, 1],
#  [-5.828419, -35.217461, 1],
#  [-5.829496, -35.217459000000005, 1],
#  [-5.833394, -35.217458, 480],
#  [-5.831958, -35.217458, 1],
#  [-5.827980999999999, -35.217458, 1],
#  [-5.833948, -35.217456, 1],
#  [-5.829516, -35.217456, 1],
#  [-5.832043, -35.217455, 1],
#  [-5.831391, -35.217455, 1],
#  [-5.830023000000001, -35.217455, 1],
#  [-5.82945, -35.217455, 1],
#  [-5.828271, -35.217455, 1],
#  [-5.829556, -35.217453000000006, 1],
#  [-5.829421, -35.217453000000006, 480],
#  [-5.8300980000000004, -35.217451000000004, 1],
#  [-5.828361, -35.217451000000004, 1],
#  [-5.833438, -35.21745, 1],
#  [-5.831421, -35.21745, 1],
#  [-5.827918, -35.21745, 1],
#  [-5.830025, -35.217448, 1],
#  [-5.829575, -35.217448, 1],
#  [-5.828463, -35.217446, 480],
#  [-5.833425, -35.217442999999996, 1],
#  [-5.833438, -35.21744, 1],
#  [-5.831871, -35.21744, 1],
#  [-5.829463, -35.21744, 1],
#  [-5.831901, -35.217438, 1],
#  [-5.831341, -35.217438, 1],
#  [-5.82791, -35.217438, 1],
#  [-5.828323, -35.217436, 1],
#  [-5.828308, -35.217436, 1],
#  [-5.828298, -35.217436, 1],
#  [-5.828335, -35.217434999999995, 1],
#  [-5.82955, -35.217433, 1],
#  [-5.8295010000000005, -35.217433, 1],
#  [-5.828333, -35.217431, 1],
#  [-5.8282680000000004, -35.217431, 1],
#  [-5.828286, -35.21743, 1],
#  [-5.8318449999999995, -35.217428000000005, 1],
#  [-5.831315, -35.217428000000005, 1],
#  [-5.829586, -35.217428000000005, 1],
#  [-5.8318330000000005, -35.217426, 1],
#  [-5.831765, -35.217426, 1],
#  [-5.831836, -35.217425, 1],
#  [-5.83183, -35.217425, 1],
#  [-5.831991, -35.217421, 480],
#  [-5.833449, -35.217420000000004, 1],
#  [-5.8300980000000004, -35.217420000000004, 1],
#  [-5.831336, -35.217418, 1],
#  [-5.829599, -35.217418, 1],
#  [-5.831837999999999, -35.217414, 1],
#  [-5.830186, -35.217414, 1],
#  [-5.828176, -35.217414, 1],
#  [-5.833418, -35.217413, 1],
#  [-5.8295650000000006, -35.217413, 1],
#  [-5.828371, -35.217413, 480],
#  [-5.833439, -35.217411, 1],
#  [-5.833426, -35.217411, 1],
#  [-5.833413, -35.217411, 1],
#  [-5.8301050000000005, -35.217411, 1],
#  [-5.829629, -35.217411, 1],
#  [-5.829536, -35.217411, 480],
#  [-5.828266, -35.217411, 1],
#  [-5.829661, -35.21741, 1],
#  [-5.831911, -35.217408, 1],
#  [-5.831253, -35.217401, 1],
#  [-5.827884, -35.217401, 1],
#  [-5.83175, -35.2174, 1],
#  [-5.831233999999999, -35.2174, 1],
#  [-5.828256, -35.2174, 1],
#  [-5.828208999999999, -35.2174, 1],
#  [-5.833473000000001, -35.217397999999996, 1],
#  [-5.829685, -35.217397999999996, 1],
#  [-5.829575, -35.217397999999996, 1],
#  [-5.828235, -35.217397999999996, 1],
#  [-5.83179, -35.217396, 1],
#  [-5.828248, -35.217396, 1],
#  [-5.828226, -35.217395, 1],
#  [-5.827833, -35.217395, 1],
#  [-5.830175, -35.21739, 1],
#  [-5.8282, -35.21739, 1],
#  [-5.828180000000001, -35.21739, 1],
#  [-5.831638, -35.217388, 1],
#  [-5.829658, -35.217388, 1],
#  [-5.82961, -35.217388, 1],
#  [-5.8302760000000005, -35.217386, 1],
#  [-5.831723, -35.217385, 1],
#  [-5.833434, -35.217383, 1],
#  [-5.831718, -35.217383, 1],
#  [-5.830188, -35.217383, 1],
#  [-5.8278300000000005, -35.217383, 1],
#  [-5.83343, -35.217381, 480],
#  [-5.829693, -35.217381, 1],
#  [-5.831718, -35.21738, 1],
#  [-5.831246, -35.21738, 1],
#  [-5.831163, -35.21738, 1],
#  [-5.833461, -35.217378000000004, 1],
#  [-5.831144, -35.217378000000004, 1],
#  [-5.831718, -35.217376, 1],
#  [-5.828281, -35.217375, 480],
#  [-5.829701, -35.217372999999995, 1],
#  [-5.828085, -35.217372999999995, 1],
#  [-5.828175, -35.217371, 1],
#  [-5.830254, -35.217369, 1],
#  [-5.831716, -35.217368, 1],
#  [-5.830368, -35.217368, 1],
#  [-5.8318449999999995, -35.217366, 480],
#  [-5.829766, -35.217366, 1],
#  [-5.8296779999999995, -35.217366, 1],
#  [-5.829745, -35.217363, 1],
#  [-5.828183, -35.217363, 1],
#  [-5.829651, -35.217361, 480],
#  [-5.831775, -35.21736, 1],
#  [-5.831054, -35.21736, 1],
#  [-5.828125, -35.21736, 1],
#  [-5.833981, -35.217358000000004, 1],
#  [-5.8334529999999996, -35.217358000000004, 1],
#  [-5.831651, -35.217358000000004, 1],
#  [-5.828168, -35.217358000000004, 1],
#  [-5.833471, -35.217356, 1],
#  [-5.831691, -35.217356, 1],
#  [-5.8281480000000006, -35.217356, 1],
#  [-5.830335, -35.217355, 1],
#  [-5.831073, -35.217353, 1],
#  [-5.8302760000000005, -35.217353, 1],
#  [-5.830452999999999, -35.217351, 1],
#  [-5.828145, -35.217351, 1],
#  [-5.830968, -35.21735, 1],
#  [-5.829685, -35.21735, 1],
#  [-5.828115, -35.217348, 1],
#  [-5.8280959999999995, -35.217348, 1],
#  [-5.833485, -35.217346, 1],
#  [-5.8316300000000005, -35.217346, 1],
#  [-5.831148000000001, -35.217345, 1],
#  [-5.829798, -35.217345, 1],
#  [-5.830979, -35.21734, 1],
#  [-5.830452999999999, -35.21734, 1],
#  [-5.829768, -35.21734, 1],
#  [-5.829716, -35.21734, 1],
#  [-5.830565, -35.217338, 1],
#  [-5.827801, -35.217338, 1],
#  [-5.827749, -35.217338, 1],
#  [-5.830781, -35.217335, 1],
#  [-5.8298, -35.217335, 1],
#  [-5.828194, -35.217335, 480],
#  [-5.830673, -35.217333, 1],
#  [-5.830568, -35.217333, 1],
#  [-5.8303650000000005, -35.217333, 1],
#  [-5.833458, -35.217331, 1],
#  [-5.8315980000000005, -35.217331, 1],
#  [-5.830876, -35.217331, 1],
#  [-5.831569, -35.21733, 1],
#  [-5.830783, -35.21733, 1],
#  [-5.827748000000001, -35.21733, 1],
#  [-5.833475, -35.217328, 1],
#  [-5.830884999999999, -35.217328, 1],
#  [-5.830678, -35.217328, 1],
#  [-5.829803, -35.217328, 1],
#  [-5.828085, -35.217328, 1],
#  [-5.827998, -35.217328, 1],
#  [-5.831528, -35.217326, 1],
#  [-5.831036, -35.217326, 1],
#  [-5.831585, -35.217324, 1],
#  [-5.828111, -35.217323, 1],
#  [-5.82987, -35.217321000000005, 1],
#  [-5.833501, -35.21732, 1],
#  [-5.828091000000001, -35.217318, 1],
#  [-5.828044, -35.217318, 1],
#  [-5.83346, -35.217316, 1],
#  [-5.83156, -35.217316, 1],
#  [-5.8304480000000005, -35.217316, 1],
#  [-5.829791, -35.217316, 1],
#  [-5.833451, -35.217313, 1],
#  [-5.828066000000001, -35.217313, 1],
#  [-5.833518, -35.217310999999995, 1],
#  [-5.831585, -35.217310999999995, 1],
#  [-5.82986, -35.217310999999995, 1],
#  [-5.829768, -35.21731, 480],
#  [-5.8317, -35.217308, 480],
#  [-5.8334660000000005, -35.217306, 1],
#  [-5.831571, -35.217304999999996, 1],
#  [-5.828066000000001, -35.217304999999996, 1],
#  [-5.8316360000000005, -35.217303, 1],
#  [-5.830531, -35.217303, 1],
#  [-5.828035, -35.217303, 1],
#  [-5.828014, -35.217303, 1],
#  [-5.830928, -35.217301, 1],
#  [-5.831524, -35.217298, 1],
#  [-5.829796, -35.217298, 1],
#  [-5.8314900000000005, -35.217296000000005, 1],
#  [-5.829915, -35.217293, 1],
#  [-5.83082, -35.217290999999996, 1],
#  [-5.830615, -35.217290999999996, 1],
#  [-5.829880999999999, -35.217290999999996, 1],
#  [-5.829826000000001, -35.217290999999996, 1],
#  [-5.828113, -35.217290999999996, 480],
#  [-5.829909, -35.217290000000006, 1],
#  [-5.8307, -35.217288, 1],
#  [-5.829905999999999, -35.217285, 1],
#  [-5.8277209999999995, -35.217283, 1],
#  [-5.833473000000001, -35.217281, 480],
#  [-5.827996, -35.217281, 1],
#  [-5.831462999999999, -35.217279, 1],
#  [-5.827966, -35.217279, 1],
#  [-5.827916, -35.217279, 1],
#  [-5.827662999999999, -35.217279, 1],
#  [-5.829973000000001, -35.217278, 1],
#  [-5.828018, -35.217278, 1],
#  [-5.833508999999999, -35.217276, 1],
#  [-5.8316230000000004, -35.217276, 480],
#  [-5.833491, -35.217275, 1],
#  [-5.827666000000001, -35.217273, 1],
#  [-5.831561, -35.217271000000004, 1],
#  [-5.833506, -35.21727, 1],
#  [-5.831441000000001, -35.217268, 1],
#  [-5.8314330000000005, -35.217268, 1],
#  [-5.829905999999999, -35.217268, 1],
#  [-5.82799, -35.217268, 1],
#  [-5.831388, -35.217265999999995, 1],
#  [-5.831405, -35.217265000000005, 1],
#  [-5.829975, -35.217263, 1],
#  [-5.834011, -35.217259999999996, 1],
#  [-5.827991, -35.217258, 1],
#  [-5.827935, -35.217258, 1],
#  [-5.831428, -35.217256, 1],
#  [-5.829886, -35.217256, 480],
#  [-5.8279559999999995, -35.217255, 1],
#  [-5.831430999999999, -35.217251, 1],
#  [-5.831398, -35.217251, 1],
#  [-5.833494, -35.21725, 1],
#  [-5.8299080000000005, -35.217248, 1],
#  [-5.833506, -35.217246, 1],
#  [-5.830021, -35.217246, 1],
#  [-5.8280330000000005, -35.217246, 480],
#  [-5.831539, -35.217245, 480],
#  [-5.830035, -35.217245, 1],
#  [-5.83001, -35.217245, 1],
#  [-5.829936, -35.217245, 1],
#  [-5.829994999999999, -35.217242999999996, 1],
#  [-5.8279760000000005, -35.217242999999996, 1],
#  [-5.8335349999999995, -35.217240999999994, 1],
#  [-5.831483, -35.217240000000004, 1],
#  [-5.831353, -35.217240000000004, 1],
#  [-5.831304, -35.217240000000004, 1],
#  [-5.827891, -35.217240000000004, 1],
#  [-5.830074, -35.217238, 1],
#  [-5.831315, -35.217236, 1],
#  [-5.827946, -35.217236, 1],
#  [-5.833526, -35.217234000000005, 1],
#  [-5.831308, -35.217234000000005, 1],
#  [-5.827911, -35.217233, 1],
#  [-5.827834999999999, -35.217233, 1],
#  [-5.83355, -35.217228000000006, 1],
#  [-5.831341, -35.217228000000006, 1],
#  [-5.827641000000001, -35.217228000000006, 1],
#  [-5.833496, -35.217225, 1],
#  [-5.830025, -35.217225, 1],
#  [-5.833476, -35.217221, 1],
#  [-5.827915, -35.217221, 1],
#  [-5.830091, -35.217220000000005, 1],
#  [-5.827573999999999, -35.217220000000005, 1],
#  [-5.8335, -35.217218, 1],
#  [-5.831298, -35.217215, 1],
#  [-5.827913, -35.217215, 1],
#  [-5.8275809999999995, -35.217215, 1],
#  [-5.831453, -35.217213, 480],
#  [-5.83127, -35.217213, 1],
#  [-5.8278550000000005, -35.217213, 1],
#  [-5.8314010000000005, -35.217211, 1],
#  [-5.831218, -35.217211, 1],
#  [-5.831230000000001, -35.217209999999994, 1],
#  [-5.827883, -35.217209999999994, 1],
#  [-5.8312230000000005, -35.217208, 1],
#  [-5.830155, -35.217208, 1],
#  [-5.830133, -35.217206, 1],
#  [-5.830113, -35.217206, 1],
#  [-5.830005, -35.217206, 480],
#  [-5.833503, -35.217205, 480],
#  [-5.831251, -35.217203000000005, 1],
#  [-5.830179, -35.217203000000005, 1],
#  [-5.830108, -35.217203000000005, 1],
#  [-5.830048000000001, -35.217203000000005, 1],
#  [-5.827954, -35.217203000000005, 480],
#  [-5.831278, -35.217201, 1],
#  [-5.830023000000001, -35.217201, 1],
#  [-5.831253, -35.2172, 1],
#  [-5.833516, -35.217195000000004, 1],
#  [-5.827875, -35.217195000000004, 1],
#  [-5.82782, -35.217195000000004, 1],
#  [-5.831123000000001, -35.217189000000005, 1],
#  [-5.83122, -35.217188, 1],
#  [-5.831183, -35.217186, 1],
#  [-5.8311459999999995, -35.217186, 1],
#  [-5.830141, -35.217186, 1],
#  [-5.831361, -35.217185, 480],
#  [-5.831313, -35.217183, 1],
#  [-5.830203, -35.217183, 1],
#  [-5.827831, -35.217183, 1],
#  [-5.827758, -35.217183, 1],
#  [-5.831173000000001, -35.21718, 1],
#  [-5.831126, -35.21718, 1],
#  [-5.831196, -35.217178000000004, 1],
#  [-5.830271, -35.217178000000004, 1],
#  [-5.833548, -35.217176, 1],
#  [-5.830248, -35.217176, 1],
#  [-5.830218, -35.217175, 1],
#  [-5.827839, -35.217175, 1],
#  [-5.83116, -35.217172999999995, 1],
#  [-5.830285, -35.217172999999995, 1],
#  [-5.831030999999999, -35.217171, 1],
#  [-5.827838, -35.217171, 1],
#  [-5.830223, -35.21717, 1],
#  [-5.830161, -35.21717, 1],
#  [-5.83114, -35.217168, 1],
#  [-5.83106, -35.217166, 1],
#  [-5.827839, -35.217166, 1],
#  [-5.827776, -35.217166, 1],
#  [-5.8335349999999995, -35.217165, 1],
#  [-5.83404, -35.217163, 1],
#  [-5.831091000000001, -35.217163, 1],
#  [-5.830138, -35.217163, 1],
#  [-5.827808999999999, -35.217163, 1],
#  [-5.830125, -35.217161, 480],
#  [-5.833551, -35.217158000000005, 1],
#  [-5.833531, -35.217158000000005, 1],
#  [-5.831112999999999, -35.217158000000005, 1],
#  [-5.831024, -35.217158000000005, 1],
#  [-5.827876, -35.217158000000005, 480],
#  [-5.827498, -35.217158000000005, 1],
#  [-5.827488, -35.217158000000005, 1],
#  [-5.831086, -35.217156, 1],
#  [-5.831268, -35.217155, 480],
#  [-5.8312230000000005, -35.217155, 1],
#  [-5.830934, -35.217155, 1],
#  [-5.830388, -35.217155, 1],
#  [-5.8303199999999995, -35.217155, 1],
#  [-5.830255999999999, -35.217155, 1],
#  [-5.830361, -35.217153, 1],
#  [-5.8310580000000005, -35.217151, 1],
#  [-5.827805000000001, -35.217151, 1],
#  [-5.830964, -35.21715, 1],
#  [-5.830323, -35.21715, 1],
#  [-5.827751, -35.21715, 1],
#  [-5.833556, -35.217148, 1],
#  [-5.831061, -35.217148, 1],
#  [-5.830389, -35.217148, 1],
#  [-5.827536, -35.217148, 1],
#  [-5.831024, -35.217143, 1],
#  [-5.830996, -35.217143, 1],
#  [-5.830921, -35.217143, 1],
#  [-5.830833, -35.217143, 1],
#  [-5.8303400000000005, -35.217141, 1],
#  [-5.830278, -35.217141, 1],
#  [-5.833518, -35.21714, 1],
#  [-5.8305050000000005, -35.21714, 1],
#  [-5.830971, -35.217138, 1],
#  [-5.830866, -35.217138, 1],
#  [-5.833578, -35.217135999999996, 1],
#  [-5.830996, -35.217135999999996, 1],
#  [-5.830728, -35.217135999999996, 1],
#  [-5.830435, -35.217135999999996, 1],
#  [-5.830616, -35.217135, 1],
#  [-5.830475, -35.217135, 1],
#  [-5.830814, -35.217131, 1],
#  [-5.830495, -35.217131, 1],
#  [-5.830426, -35.217131, 1],
#  [-5.830373000000001, -35.217131, 1],
#  [-5.827751, -35.217131, 1],
#  [-5.830254, -35.21713, 1],
#  [-5.827764, -35.21713, 1],
#  [-5.827683, -35.21713, 1],
#  [-5.833578, -35.217128, 1],
#  [-5.831169, -35.217128, 480],
#  [-5.83113, -35.217128, 1],
#  [-5.830958, -35.217128, 1],
#  [-5.830931, -35.217128, 1],
#  [-5.830881, -35.217128, 1],
#  [-5.830765, -35.217128, 1],
#  [-5.833538, -35.217126, 480],
#  [-5.830895, -35.217126, 1],
#  [-5.83059, -35.217126, 1],
#  [-5.83079, -35.217125, 1],
#  [-5.830703, -35.217125, 1],
#  [-5.830546, -35.217125, 1],
#  [-5.827761, -35.217125, 1],
#  [-5.830901, -35.217123, 1],
#  [-5.830655999999999, -35.217123, 1],
#  [-5.830248, -35.217123, 480],
#  [-5.833508999999999, -35.217121, 1],
#  [-5.830693, -35.217121, 1],
#  [-5.830595, -35.217121, 1],
#  [-5.830456, -35.217121, 1],
#  [-5.830393, -35.21712, 1],
#  [-5.830836, -35.217118, 1],
#  [-5.830531, -35.217116, 1],
#  [-5.8304849999999995, -35.217116, 1],
#  [-5.82774, -35.217116, 1],
#  [-5.827698000000001, -35.217116, 1],
#  [-5.833551, -35.217115, 1],
#  [-5.833538, -35.217115, 1],
#  [-5.830851, -35.217115, 1],
#  [-5.8307910000000005, -35.217115, 1],
#  [-5.8308029999999995, -35.217113, 1],
#  [-5.830736, -35.217110999999996, 1],
#  [-5.830635, -35.217110999999996, 1],
#  [-5.830571, -35.217110999999996, 1],
#  [-5.827801, -35.217110999999996, 480],
#  [-5.8307, -35.21711, 1],
#  [-5.8306830000000005, -35.21711, 1],
#  [-5.830593, -35.21711, 1],
#  [-5.831064, -35.217108, 480],
#  [-5.831030999999999, -35.217108, 1],
#  [-5.830511, -35.217106, 1],
#  [-5.827735, -35.217106, 1],
#  [-5.827683, -35.217105, 1],
#  [-5.830741000000001, -35.217103, 1],
#  [-5.830369, -35.217103, 1],
#  [-5.8306260000000005, -35.217101, 1],
#  [-5.833573, -35.217098, 1],
#  [-5.830369, -35.217096000000005, 480],
#  [-5.827418, -35.217096000000005, 1],
#  [-5.83093, -35.217093, 1],
#  [-5.8274, -35.217093, 1],
#  [-5.830956, -35.21709, 480],
#  [-5.8304860000000005, -35.217086, 1],
#  [-5.830825, -35.217085, 1],
#  [-5.827706, -35.217083, 1],
#  [-5.8276900000000005, -35.217081, 1],
#  [-5.8307150000000005, -35.217079999999996, 1],
#  [-5.830601000000001, -35.217079999999996, 1],
#  [-5.833563, -35.217078, 1],
#  [-5.830846, -35.217078, 480],
#  [-5.830491, -35.217078, 480],
#  [-5.827671, -35.217078, 1],
#  [-5.827686, -35.217076, 1],
#  [-5.827608000000001, -35.217075, 1],
#  [-5.8274230000000005, -35.217073, 1],
#  [-5.83073, -35.217071000000004, 480],
#  [-5.830613, -35.217071000000004, 480],
#  [-5.8276699999999995, -35.21707, 1],
#  [-5.827621, -35.217065999999996, 1],
#  [-5.827726, -35.217065000000005, 480],
#  [-5.834083000000001, -35.217063, 1],
#  [-5.833565, -35.217063, 1],
#  [-5.83359, -35.217061, 1],
#  [-5.8276650000000005, -35.21706, 1],
#  [-5.833545, -35.217051, 1],
#  [-5.827335, -35.217040000000004, 1],
#  [-5.833608, -35.217038, 1],
#  [-5.833596, -35.217036, 1],
#  [-5.833566, -35.217034999999996, 480],
#  [-5.833563, -35.217034999999996, 1],
#  [-5.827616, -35.217033, 1],
#  [-5.827308, -35.217033, 1],
#  [-5.83358, -35.217026000000004, 1],
#  [-5.82761, -35.217026000000004, 1],
#  [-5.827595, -35.217026000000004, 1],
#  [-5.827533, -35.217025, 1],
#  [-5.8276010000000005, -35.217023, 1],
#  [-5.833543, -35.217017999999996, 1],
#  [-5.83362, -35.217016, 1],
#  [-5.833601, -35.217016, 1],
#  [-5.827653, -35.217016, 480],
#  [-5.827554, -35.217016, 1],
#  [-5.827595, -35.217015, 1],
#  [-5.827545, -35.217015, 1],
#  [-5.827318, -35.217001, 1],
#  [-5.827578, -35.216998, 1],
#  [-5.827543, -35.216985, 1],
#  [-5.827255999999999, -35.216983, 1],
#  [-5.833588, -35.216981, 1],
#  [-5.827535, -35.216978000000005, 1],
#  [-5.833625, -35.216976, 1],
#  [-5.827518, -35.216975, 1],
#  [-5.834125, -35.216972999999996, 1],
#  [-5.827459999999999, -35.216972999999996, 1],
#  [-5.827221, -35.216972999999996, 1],
#  [-5.827526, -35.21697, 1],
#  [-5.8275809999999995, -35.216968, 480],
#  [-5.82747, -35.216964000000004, 1],
#  [-5.833595, -35.216963, 1],
#  [-5.833576, -35.216963, 1],
#  [-5.833591, -35.216956, 1],
#  [-5.833596, -35.216945, 480],
#  [-5.833641, -35.216941, 1],
#  [-5.833608, -35.21694, 1],
#  [-5.827473, -35.216936, 1],
#  [-5.833635, -35.216935, 1],
#  [-5.82747, -35.216933000000004, 1],
#  [-5.82722, -35.216933000000004, 1],
#  [-5.827433, -35.21693, 1],
#  [-5.827175, -35.21693, 1],
#  [-5.827459999999999, -35.216926, 1],
#  [-5.827443, -35.216923, 1],
#  [-5.82739, -35.216923, 1],
#  [-5.827508, -35.216921, 480],
#  [-5.833645, -35.216918, 1],
#  [-5.8274550000000005, -35.216915, 1],
#  [-5.827136, -35.216915, 1],
#  [-5.827394, -35.216910999999996, 1],
#  [-5.833575, -35.216908000000004, 1],
#  [-5.833658, -35.216901, 1],
#  [-5.833659, -35.21689, 1],
#  [-5.827401, -35.216888, 1],
#  [-5.833623, -35.216885999999995, 1],
#  [-5.83416, -35.216885, 1],
#  [-5.83361, -35.216883, 1],
#  [-5.827393, -35.216881, 1],
#  [-5.833626000000001, -35.216879, 1],
#  [-5.827386, -35.216878, 1],
#  [-5.827121, -35.216876, 1],
#  [-5.827436, -35.216873, 480],
#  [-5.827369999999999, -35.216873, 1],
#  [-5.827319, -35.216873, 1],
#  [-5.827083999999999, -35.216871000000005, 1],
#  [-5.833631, -35.216865000000006, 1],
#  [-5.8342480000000005, -35.216861, 1],
#  [-5.83364, -35.21686, 480],
#  [-5.8273209999999995, -35.21686, 1],
#  [-5.82705, -35.216854999999995, 1],
#  [-5.8336760000000005, -35.21685, 1],
#  [-5.834328, -35.216848, 1],
#  [-5.833641, -35.216848, 1],
#  [-5.833673, -35.216845, 1],
#  [-5.8273410000000005, -35.216845, 1],
#  [-5.827311, -35.216845, 1],
#  [-5.82733, -35.216836, 1],
#  [-5.827331, -35.216833, 1],
#  [-5.827311, -35.216828, 1],
#  [-5.827364, -35.216826, 480],
#  [-5.827246, -35.216825, 1],
#  [-5.827294, -35.216823, 1],
#  [-5.83368, -35.21682, 1],
#  [-5.827024, -35.216811, 1],
#  [-5.833651000000001, -35.216809999999995, 1],
#  [-5.8336, -35.216808, 1],
#  [-5.827248, -35.216806, 1],
#  [-5.826988, -35.216805, 1],
#  [-5.833691, -35.216801000000004, 1],
#  [-5.833661, -35.2168, 1],
#  [-5.82696, -35.216796, 1],
#  [-5.827259, -35.216793, 1],
#  [-5.833651000000001, -35.216789, 1],
#  [-5.8272580000000005, -35.216786, 1],
#  [-5.833703, -35.216784000000004, 1],
#  [-5.83367, -35.21678, 480],
#  [-5.827293, -35.216778000000005, 480],
#  [-5.8272379999999995, -35.216776, 1],
#  [-5.827175, -35.216775, 1],
#  [-5.827223, -35.216772999999996, 1],
#  [-5.82719, -35.216761, 1],
#  [-5.827216, -35.216758, 1],
#  [-5.827173, -35.216758, 1],
#  [-5.834383, -35.216756, 1],
#  [-5.827208000000001, -35.216755, 1],
#  [-5.833715, -35.216753000000004, 1],
#  [-5.83367, -35.216753000000004, 1],
#  [-5.833695, -35.21675, 1],
#  [-5.833683000000001, -35.216746, 1],
#  [-5.833665, -35.216743, 1],
#  [-5.826926, -35.216743, 1],
#  [-5.827184, -35.216736, 1],
#  [-5.833723, -35.216735, 1],
#  [-5.826885, -35.216735, 1],
#  [-5.826868, -35.216735, 1],
#  [-5.827221, -35.216728, 480],
#  [-5.8336879999999995, -35.216726, 1],
#  ...]

# %% [markdown]
# ## 1) Heatmap

# %%
# =================================================================================
# Heatmap generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Create map object
htMap = folium.Map(location=mapc, zoom_start=zoom)
# minimap = MiniMap()

# Append the coordinates to the heatMap
HeatMap(coordinates).add_to(htMap)

# Add the minimap
# htMap.add_child(minimap)

# Print the heatMap
htMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 1.1) Heatmap by period

# %% [markdown]
# ## 2) Map markers

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Map markers generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# For speed purposes
MAX_RECORDS = 2000

# Create map object
map_activities = folium.Map(location=mapc, zoom_start=zoom)

plugins.MarkerCluster(coordinates).add_to(map_activities)

map_activities.save(os.path.join('results', 'Plugins_1.html'))

# Show the map
map_activities
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-3eb30ff21a85> in <module>()
#      20 map_activities = folium.Map(location=mapc, zoom_start=zoom)
#      21
# ---> 22 marker_cluster = plugins.MarkerCluster("Activities").add_to(map_activities)
#      23
#      24 # Add the coordinates to the coordinate
#
# /anaconda2/lib/python2.7/site-packages/folium/plugins/marker_cluster.pyc in __init__(self, locations, popups, icons, name, overlay, control, show, icon_create_function, options)
#      71                 p = popup if self._validate(popup, Popup) else Popup(popup)
#      72                 i = icon if self._validate(icon, Icon) else Icon(icon)
# ---> 73                 self.add_child(Marker(location, popup=p, icon=i))
#      74
#      75         options = {} if options is None else options
#
# /anaconda2/lib/python2.7/site-packages/folium/map.pyc in __init__(self, location, popup, tooltip, icon)
#     248         self._name = 'Marker'
#     249         self.tooltip = tooltip
# --> 250         self.location = _validate_coordinates(location)
#     251         if icon is not None:
#     252             self.add_child(icon)
#
# /anaconda2/lib/python2.7/site-packages/folium/utilities.pyc in _validate_coordinates(coordinates)
#      42 def _validate_coordinates(coordinates):
#      43     """Validates multiple coordinates for the various markers in folium."""
# ---> 44     if _isnan(coordinates):
#      45         raise ValueError('Location values cannot contain NaNs, '
#      46                          'got:\n{!r}'.format(coordinates))
#
# /anaconda2/lib/python2.7/site-packages/folium/utilities.pyc in _isnan(values)
#      68 def _isnan(values):
#      69     """Check if there are NaNs values in the iterable."""
# ---> 70     return any(math.isnan(value) for value in _flatten(values))
#      71
#      72
#
# /anaconda2/lib/python2.7/site-packages/folium/utilities.pyc in <genexpr>((value,))
#      68 def _isnan(values):
#      69     """Check if there are NaNs values in the iterable."""
# ---> 70     return any(math.isnan(value) for value in _flatten(values))
#      71
#      72
#
# TypeError: a float is required

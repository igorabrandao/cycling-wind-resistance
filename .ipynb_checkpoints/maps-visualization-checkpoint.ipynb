# %% [markdown]
# # Programming Project - Unit 2
# *by Débora Azevedo, Eliseu Jayro, Francisco de Paiva and Igor Brandão*
#
# **Goals**
# The purpose of this project is explore the following:
#
# - Access Health Graph API - Runkeeper content;
# - Geolocation analysis and hypotheses should be explained in detail;

# %% [markdown]
# <hr>

# %% [markdown]
# # Global Imports section
#
# Import the necessary libraries to handle
#
# - Geocoding;
# - Maps;
# - File input;
# - Heatmap;
# - Numpy library;
# - Tqdm progress bar

# %%
### Library necessary to run this IPython Notebook
# !pip install geocoder
# !pip install folium
# !pip install tqdm
# !pip install tabulate
# !pip install pandas-datareader

# %%
# Import pandas
import pandas as pd

# Import google geocoder
import geocoder as gc

# Import numpy library
import numpy as np

# Import folium maps
import os
import folium
from folium import plugins

# Import tqdm progressing bar plugin
from tqdm import tqdm

# %% [markdown]
# <hr>

# %% [markdown]
# # I - Maps section

# %% [markdown]
# ## Geolocation data import [optional]

# %%
# Import the geolocation.csv data: data
geolocation_data = pd.read_csv("geolocation2018.csv", encoding = 'latin2')

# %% [markdown]
# ### Coordinate groupping
#
# The cell below perform the latitude/longitude reading and count all og them to know if there are repetitions and group *[latitude, longitude, count]* data into the coordinate array

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Add the coordinates
# =================================================================================

# Initialize the coordinates array
coordinates = []

# Add the coordinates to the coordinate
for i in tqdm(range(len(geodata))):
    # eliminate items with'nan' element
    if all(~np.isnan([geodata.loc[geodata.index[i],'latitude'], geodata.loc[geodata.index[i],'longitude']])):
        coordinates.append([geodata.loc[geodata.index[i],'latitude'], geodata.loc[geodata.index[i],'longitude'], geodata.loc[geodata.index[i],'count']])

# Display the imported coordinates
coordinates
# Out:
#   0%|          | 0/110216 [00:00<?, ?it/s]Exception KeyError: KeyError(<weakref at 0x128ba84c8; to 'tqdm' at 0x140baec50>,) in <bound method tqdm.__del__ of   0%|          | 0/110216 [00:00<?, ?it/s]> ignored
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-b7aa9a9cc3a0> in <module>()
#      17     # eliminate items with'nan' element
#      18     if all(~np.isnan([geodata.loc[geodata.index[i],'latitude'], geodata.loc[geodata.index[i],'longitude']])):
# ---> 19         coordinates.append([geodata.loc[geodata.index[i],'latitude'], geodata.loc[geodata.index[i],'longitude'], geodata.loc[geodata.index[i],'count']])
#      20
#      21 # Display the imported coordinates
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#    1025                     return section
#    1026                 # This is an elided recursive call to iloc/loc/etc'
# -> 1027                 return getattr(section, self.name)[new_key]
#    1028
#    1029         raise IndexingError('not applicable')
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# /anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: u'the label [count] is not in the [index]'

# %% [markdown]
# ## 1) Heatmap

# %%
# =================================================================================
# Heatmap generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# Create map object
htMap = folium.Map(location=mapc, zoom_start=zoom)

# Append the coordinates to the heatMap
HeatMap(coordinates).add_to(htMap)

# Print the heatMap
htMap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 1.1) Heatmap by period

# %% [markdown]
# ## 2) Map markers

# %%
# =================================================================================
# Data adjusts
# =================================================================================

# Count the same latitude/longitude occurrences
geodata = geolocation_data.groupby(['longitude', 'latitude']).size().reset_index().rename(columns={0:'count'})

# =================================================================================
# Map markers generation
# =================================================================================

# Set map center and zoom level
mapc = [-5.788, -35.202]
zoom = 11

# For speed purposes
MAX_RECORDS = 2000

# Create map object
map_activities = folium.Map(location=mapc, zoom_start=zoom)

plugins.MarkerCluster(coordinates).add_to(map_activities)

# map_activities.save(os.path.join('results', 'Plugins_1.html'))

# Show the map
map_activities
